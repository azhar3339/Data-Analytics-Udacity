# %% [markdown]
# <a href="https://colab.research.google.com/github/azhar3339/Data-Analytics-Udacity/blob/master/22_llama_3_2_fine_tuning_with_torchtune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Dec  7 19:07:06 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install -Uqqq pip --progress-bar off
# !pip install -qqq torchtune==0.3.1 --progress-bar off
# !pip install -qqq torchao==0.6.1 --progress-bar off
# !pip install -qqq transformers==4.46.1 --progress-bar off
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
import json
import re
from pathlib import Path
from typing import List

import numpy as np
import pandas as pd
import torch
from google.colab import userdata
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %matplotlib inline
# %config InlineBackend.figure_format='retina'


RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv("finance_training_data_v1.csv")

# %%
df.head()
# Out:
#                              Question  \
# 0  Get average contribution by gender
# 1       Get average premium by gender
# 2          Get burning cost by gender
# 3                Get claims by gender
# 4              Get exposure by gender
#
#                                               Answer
# 0  {'name': 'get_metric', 'parameters': {'metric'...
# 1  {'name': 'get_metric', 'parameters': {'metric'...
# 2  {'name': 'get_metric', 'parameters': {'metric'...
# 3  {'name': 'get_metric', 'parameters': {'metric'...
# 4  {'name': 'get_metric', 'parameters': {'metric'...

# %%
df.shape
# Out:
# (190, 2)

# %%
def create_prompt(question: str):
    prompt = """
You are an expert in composing functions. You are given a question and a set of possible functions.
Based on the question, you will need to make one or more function/tool calls to achieve the purpose.
If none of the functions can be used, point it out. If the given question lacks the parameters required by the function, also point it out. You should only return the function call in the tools call sections.
Avoid making guesses and providing speculative information, or giving incomplete responses.
All the parameters are optional, if any parameter is not required to answer the user's query, leave it empty.
If you decide to invoke any of the function(s), you MUST put it in json format like below:
{
    "name": "get_metric",
    "parameters": {
        "metric": "get_unit_cost",
        "filters": {
            "povider_network": "NW6"
        },
        "groupby": "gender"
    }
}
You SHOULD NOT include any other text in the response.

Here is a list of functions in JSON format that you can invoke:

[
    {
        "name": "get_metric",
        "description": "Retrieve specific metrics based on filters and groupings.",
        "parameters": {
            "type": "dict",
            "required": [],
            "properties": {
                "metric": {
                    "type": "string",
                    "enum": [
                        "get_premium",
                        "get_avg_contribution",
                        "get_unit_cost"
                    ]
                },
                "filters": {
                    "type": "object",
                    "properties": {
                        "stating_period": {
                            "type": "string",
                            "description": "Starting period in YYYYMM format. Defaults to 2024 if year is not mentioned."
                        },
                        "ending_period": {
                            "type": "string",
                            "description": "Ending period in YYYYMM format. Defaults to same value as starting period if not mentioned."
                        },
                        "quarter": {
                            "type": "string",
                            "enum": ["Q1", "Q2", "Q3", "Q4"]
                        },
                        "age": {
                            "type": "integer",
                            "description": "Age of the members."
                        },
                        "gender": {
                            "type": "string",
                            "enum": ["M", "F", ""]
                        },
                        "membership_type": {
                            "type": "string",
                            "enum": ["employee", "wife", "parent", "dependent", "others", ""]
                        },
                        "plan_network": {
                            "type": "string",
                            "enum": ["NW1", "NW2", "NW3", "NW4", "NW5", "NW6", "NW7", "NWS", ""]
                        },
                        "povider_network": {
                            "type": "string",
                            "enum": ["NW1", "NW2", "NW3", "NW4", "NW5", "NW6", "NW7", "NWS", ""]
                        },
                        "povider_name": {
                            "type": "string",
                            "description": "Name of the provider."
                        },
                        "provide_region": {
                            "type": "string",
                            "enum": ["eastern", "western", "central", "northern", "southern", ""]
                        },
                        "benefit_type": {
                            "type": "string",
                            "enum": ["chronic", "standard", "dental", ""]
                        },
                        "claims_type": {
                            "type": "string",
                            "enum": ["I", "O", ""],
                            "description": "I for Inpatient claims, O for Outpatient claims."
                        }
                    }
                },
                "groupby": {
                    "type": "string",
                    "description": "One of the above filters to group the results by."
                }
            }
        }
    }
]

Question:
""".strip()
    return prompt + question

# %%
def create_dataset(df):
    rows = []
    for _, row in tqdm(df.iterrows()):
        rows.append(
            {
                "input": create_prompt(row.Question),
                "output": row.Answer.lower(),
            }
        )
    return rows

# %%
train_rows = create_dataset(df)
# Out:
# 190it [00:00, 8869.33it/s]

# %%
Path("train_data.json").write_text(json.dumps(train_rows))
# Out:
# 936936

# %% [markdown]
# ## Download Model

# %%
hf_token = userdata.get("HF_TOKEN")

# %%
# !tune download "meta-llama/Llama-3.2-1B-Instruct" \
  --output-dir "./Llama-3.2-1B-Instruct" \
  --hf-token "{hf_token}" \
  --ignore-patterns "[]"
# Out:
# Ignoring files matching the following patterns: []
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]
# model.safetensors:   0% 0.00/2.47G [00:00<?, ?B/s]
#
# config.json: 100% 877/877 [00:00<00:00, 5.01MB/s]
#
#
# USE_POLICY.md: 100% 6.02k/6.02k [00:00<00:00, 29.2MB/s]
#
#
# README.md:   0% 0.00/41.7k [00:00<?, ?B/s]
#
#
# LICENSE.txt: 100% 7.71k/7.71k [00:00<00:00, 40.5MB/s]
# README.md: 100% 41.7k/41.7k [00:00<00:00, 5.16MB/s]
#
#
# generation_config.json: 100% 189/189 [00:00<00:00, 1.27MB/s]
#
#
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 10.5MB/s]
# Fetching 13 files:   8% 1/13 [00:00<00:02,  4.03it/s]
#
# consolidated.00.pth:   0% 0.00/2.47G [00:00<?, ?B/s]
#
#
# tokenizer_config.json: 100% 54.5k/54.5k [00:00<00:00, 6.85MB/s]
#
#
#
# special_tokens_map.json: 100% 296/296 [00:00<00:00, 2.23MB/s]
#
#
#
# tokenizer.json:   0% 0.00/9.09M [00:00<?, ?B/s]
#
#
#
# tokenizer.model:   0% 0.00/2.18M [00:00<?, ?B/s]
#
#
#
#
# original/params.json: 100% 220/220 [00:00<00:00, 1.33MB/s]
#
# model.safetensors:   0% 10.5M/2.47G [00:00<01:04, 38.0MB/s]
#
#
#
# tokenizer.model: 100% 2.18M/2.18M [00:00<00:00, 17.6MB/s]
#
#
# consolidated.00.pth:   0% 10.5M/2.47G [00:00<01:03, 39.0MB/s]
# model.safetensors:   1% 21.0M/2.47G [00:00<00:59, 41.5MB/s]
#
#
# tokenizer.json: 100% 9.09M/9.09M [00:00<00:00, 23.6MB/s]
#
# tokenizer.json: 100% 9.09M/9.09M [00:00<00:00, 21.5MB/s]
#
# model.safetensors:   1% 31.5M/2.47G [00:00<00:58, 41.6MB/s]
#
# consolidated.00.pth:   1% 31.5M/2.47G [00:00<00:56, 42.8MB/s]
# model.safetensors:   2% 41.9M/2.47G [00:00<00:56, 42.7MB/s]
#
# consolidated.00.pth:   2% 41.9M/2.47G [00:01<00:57, 42.3MB/s]
# model.safetensors:   2% 52.4M/2.47G [00:01<00:56, 42.6MB/s]
#
# consolidated.00.pth:   2% 52.4M/2.47G [00:01<00:57, 42.0MB/s]
# model.safetensors:   3% 62.9M/2.47G [00:01<00:56, 42.5MB/s]
#
# consolidated.00.pth:   3% 62.9M/2.47G [00:01<00:56, 42.6MB/s]
# model.safetensors:   3% 73.4M/2.47G [00:01<00:56, 42.7MB/s]
#
# consolidated.00.pth:   3% 73.4M/2.47G [00:01<00:56, 42.6MB/s]
# model.safetensors:   3% 83.9M/2.47G [00:01<00:56, 42.5MB/s]
#
# consolidated.00.pth:   3% 83.9M/2.47G [00:01<00:56, 42.3MB/s]
# model.safetensors:   4% 94.4M/2.47G [00:02<00:56, 42.4MB/s]
#
# consolidated.00.pth:   4% 94.4M/2.47G [00:02<00:56, 42.3MB/s]
# model.safetensors:   4% 105M/2.47G [00:02<00:55, 42.6MB/s]
#
# consolidated.00.pth:   4% 105M/2.47G [00:02<00:56, 42.2MB/s]
# model.safetensors:   5% 115M/2.47G [00:02<00:55, 42.3MB/s]
#
# consolidated.00.pth:   5% 115M/2.47G [00:02<00:55, 42.2MB/s]
# model.safetensors:   5% 126M/2.47G [00:02<00:55, 42.2MB/s]
#
# consolidated.00.pth:   5% 126M/2.47G [00:02<00:55, 42.2MB/s]
# model.safetensors:   6% 136M/2.47G [00:03<00:55, 42.3MB/s]
#
# consolidated.00.pth:   6% 136M/2.47G [00:03<00:55, 42.4MB/s]
# model.safetensors:   6% 147M/2.47G [00:03<00:55, 41.7MB/s]
#
# consolidated.00.pth:   6% 147M/2.47G [00:03<00:54, 42.4MB/s]
# model.safetensors:   6% 157M/2.47G [00:03<00:54, 42.6MB/s]
#
# consolidated.00.pth:   6% 157M/2.47G [00:03<00:54, 42.4MB/s]
# model.safetensors:   7% 168M/2.47G [00:03<00:53, 42.8MB/s]
#
# consolidated.00.pth:   7% 168M/2.47G [00:03<00:54, 42.5MB/s]
# model.safetensors:   7% 178M/2.47G [00:04<00:53, 42.5MB/s]
#
# consolidated.00.pth:   7% 178M/2.47G [00:04<00:53, 42.5MB/s]
# model.safetensors:   8% 189M/2.47G [00:04<00:53, 42.5MB/s]
#
# consolidated.00.pth:   8% 189M/2.47G [00:04<00:53, 42.7MB/s]
# model.safetensors:   8% 199M/2.47G [00:04<00:53, 42.3MB/s]
#
# consolidated.00.pth:   8% 199M/2.47G [00:04<00:53, 42.7MB/s]
# model.safetensors:   8% 210M/2.47G [00:04<00:53, 42.5MB/s]
#
# consolidated.00.pth:   8% 210M/2.47G [00:04<00:53, 42.6MB/s]
# model.safetensors:   9% 220M/2.47G [00:05<00:53, 42.5MB/s]
#
# consolidated.00.pth:   9% 220M/2.47G [00:05<00:52, 42.5MB/s]
# model.safetensors:   9% 231M/2.47G [00:05<00:52, 42.4MB/s]
#
# consolidated.00.pth:   9% 231M/2.47G [00:05<00:52, 42.6MB/s]
# model.safetensors:  10% 241M/2.47G [00:05<00:52, 42.5MB/s]
#
# consolidated.00.pth:  10% 241M/2.47G [00:05<00:52, 42.3MB/s]
# model.safetensors:  10% 252M/2.47G [00:05<00:52, 42.3MB/s]
#
# consolidated.00.pth:  10% 252M/2.47G [00:05<00:52, 42.5MB/s]
# model.safetensors:  11% 262M/2.47G [00:06<00:51, 42.8MB/s]
#
# consolidated.00.pth:  11% 262M/2.47G [00:06<00:52, 42.1MB/s]
# model.safetensors:  11% 273M/2.47G [00:06<00:51, 42.5MB/s]
#
# consolidated.00.pth:  11% 273M/2.47G [00:06<00:51, 42.7MB/s]
# model.safetensors:  11% 283M/2.47G [00:06<00:51, 42.6MB/s]
#
# consolidated.00.pth:  11% 283M/2.47G [00:06<00:51, 42.7MB/s]
# model.safetensors:  12% 294M/2.47G [00:06<00:51, 42.5MB/s]
#
# consolidated.00.pth:  12% 294M/2.47G [00:06<00:50, 42.9MB/s]
# model.safetensors:  12% 304M/2.47G [00:07<00:50, 42.7MB/s]
#
# consolidated.00.pth:  12% 304M/2.47G [00:07<00:50, 42.6MB/s]
# model.safetensors:  13% 315M/2.47G [00:07<00:50, 42.6MB/s]
#
# consolidated.00.pth:  13% 315M/2.47G [00:07<00:50, 42.7MB/s]
# model.safetensors:  13% 325M/2.47G [00:07<00:50, 42.3MB/s]
#
# consolidated.00.pth:  13% 325M/2.47G [00:07<00:50, 42.3MB/s]
# model.safetensors:  14% 336M/2.47G [00:07<00:50, 42.6MB/s]
#
# consolidated.00.pth:  14% 336M/2.47G [00:07<00:49, 43.0MB/s]
# model.safetensors:  14% 346M/2.47G [00:08<00:49, 42.6MB/s]
#
# consolidated.00.pth:  14% 346M/2.47G [00:08<00:49, 43.0MB/s]
# model.safetensors:  14% 357M/2.47G [00:08<00:49, 42.6MB/s]
#
# consolidated.00.pth:  14% 357M/2.47G [00:08<00:49, 43.0MB/s]
# model.safetensors:  15% 367M/2.47G [00:08<00:49, 42.3MB/s]
#
# consolidated.00.pth:  15% 367M/2.47G [00:08<00:49, 42.8MB/s]
# model.safetensors:  15% 377M/2.47G [00:08<00:49, 42.3MB/s]
#
# consolidated.00.pth:  15% 377M/2.47G [00:08<00:49, 42.5MB/s]
# model.safetensors:  16% 388M/2.47G [00:09<00:48, 42.6MB/s]
#
# consolidated.00.pth:  16% 388M/2.47G [00:09<00:49, 42.5MB/s]
# model.safetensors:  16% 398M/2.47G [00:09<00:49, 42.1MB/s]
#
# consolidated.00.pth:  16% 398M/2.47G [00:09<00:48, 42.7MB/s]
# model.safetensors:  17% 409M/2.47G [00:09<00:48, 42.3MB/s]
#
# consolidated.00.pth:  17% 409M/2.47G [00:09<00:48, 42.3MB/s]
# model.safetensors:  17% 419M/2.47G [00:09<00:48, 42.2MB/s]
#
# consolidated.00.pth:  17% 419M/2.47G [00:09<00:48, 42.8MB/s]
# model.safetensors:  17% 430M/2.47G [00:10<00:47, 42.6MB/s]
#
# consolidated.00.pth:  17% 430M/2.47G [00:10<00:47, 42.8MB/s]
# model.safetensors:  18% 440M/2.47G [00:10<00:47, 42.6MB/s]
#
# consolidated.00.pth:  18% 440M/2.47G [00:10<00:47, 42.8MB/s]
# model.safetensors:  18% 451M/2.47G [00:10<00:48, 42.0MB/s]
#
# consolidated.00.pth:  18% 451M/2.47G [00:10<00:47, 42.7MB/s]
# model.safetensors:  19% 461M/2.47G [00:10<00:47, 42.1MB/s]
#
# consolidated.00.pth:  19% 461M/2.47G [00:10<00:51, 38.8MB/s]
# model.safetensors:  19% 472M/2.47G [00:11<00:47, 42.4MB/s]
#
# consolidated.00.pth:  19% 472M/2.47G [00:11<00:46, 43.1MB/s]
# model.safetensors:  20% 482M/2.47G [00:11<00:46, 42.5MB/s]
#
# consolidated.00.pth:  20% 482M/2.47G [00:11<00:46, 43.0MB/s]
# model.safetensors:  20% 493M/2.47G [00:11<00:46, 42.6MB/s]
#
# consolidated.00.pth:  20% 493M/2.47G [00:11<00:46, 42.9MB/s]
# model.safetensors:  20% 503M/2.47G [00:13<02:27, 13.4MB/s]
#
# consolidated.00.pth:  20% 503M/2.47G [00:13<02:21, 13.9MB/s]
# model.safetensors:  21% 524M/2.47G [00:13<01:31, 21.2MB/s]
#
# consolidated.00.pth:  21% 524M/2.47G [00:13<01:29, 21.7MB/s]
# model.safetensors:  22% 535M/2.47G [00:14<01:19, 24.3MB/s]
#
# consolidated.00.pth:  22% 535M/2.47G [00:14<01:18, 24.7MB/s]
# model.safetensors:  22% 545M/2.47G [00:14<01:10, 27.4MB/s]
#
# consolidated.00.pth:  22% 545M/2.47G [00:14<01:09, 27.7MB/s]
# model.safetensors:  22% 556M/2.47G [00:14<01:03, 30.3MB/s]
#
# consolidated.00.pth:  22% 556M/2.47G [00:14<01:02, 30.6MB/s]
# model.safetensors:  23% 566M/2.47G [00:14<00:57, 33.0MB/s]
#
# consolidated.00.pth:  23% 566M/2.47G [00:14<00:57, 33.2MB/s]
# model.safetensors:  23% 577M/2.47G [00:15<00:53, 35.2MB/s]
#
# consolidated.00.pth:  23% 577M/2.47G [00:15<00:53, 35.4MB/s]
# model.safetensors:  24% 587M/2.47G [00:15<00:50, 37.0MB/s]
#
# consolidated.00.pth:  24% 587M/2.47G [00:15<00:50, 37.1MB/s]
# model.safetensors:  24% 598M/2.47G [00:15<00:48, 38.6MB/s]
#
# consolidated.00.pth:  24% 598M/2.47G [00:15<00:48, 38.5MB/s]
# model.safetensors:  25% 608M/2.47G [00:15<00:47, 39.6MB/s]
#
# consolidated.00.pth:  25% 608M/2.47G [00:15<00:47, 39.6MB/s]
# model.safetensors:  25% 619M/2.47G [00:16<00:45, 40.3MB/s]
#
# consolidated.00.pth:  25% 619M/2.47G [00:16<00:45, 40.4MB/s]
# model.safetensors:  25% 629M/2.47G [00:16<00:45, 40.9MB/s]
#
# consolidated.00.pth:  25% 629M/2.47G [00:16<00:44, 40.9MB/s]
# model.safetensors:  26% 640M/2.47G [00:16<00:44, 41.4MB/s]
#
# consolidated.00.pth:  26% 640M/2.47G [00:16<00:44, 41.4MB/s]
# model.safetensors:  26% 650M/2.47G [00:16<00:43, 41.8MB/s]
#
# consolidated.00.pth:  26% 650M/2.47G [00:16<00:43, 41.7MB/s]
# model.safetensors:  27% 661M/2.47G [00:17<00:43, 42.1MB/s]
#
# consolidated.00.pth:  27% 661M/2.47G [00:17<00:43, 41.6MB/s]
# model.safetensors:  27% 671M/2.47G [00:17<00:42, 42.3MB/s]
#
# consolidated.00.pth:  27% 671M/2.47G [00:17<00:42, 41.9MB/s]
# model.safetensors:  28% 682M/2.47G [00:17<00:42, 42.2MB/s]
#
# consolidated.00.pth:  28% 682M/2.47G [00:17<00:42, 41.8MB/s]
# model.safetensors:  28% 692M/2.47G [00:17<00:42, 42.0MB/s]
#
# consolidated.00.pth:  28% 692M/2.47G [00:17<00:42, 42.1MB/s]
# model.safetensors:  28% 703M/2.47G [00:18<00:41, 42.2MB/s]
#
# consolidated.00.pth:  28% 703M/2.47G [00:18<00:42, 41.8MB/s]
# model.safetensors:  29% 713M/2.47G [00:18<00:41, 42.1MB/s]
#
# consolidated.00.pth:  29% 713M/2.47G [00:18<00:41, 42.5MB/s]
# model.safetensors:  29% 724M/2.47G [00:18<00:41, 42.6MB/s]
#
# consolidated.00.pth:  29% 724M/2.47G [00:18<00:41, 42.6MB/s]
# model.safetensors:  30% 734M/2.47G [00:18<00:40, 42.5MB/s]
#
# consolidated.00.pth:  30% 734M/2.47G [00:18<00:41, 42.2MB/s]
# model.safetensors:  30% 744M/2.47G [00:19<00:40, 42.6MB/s]
#
# consolidated.00.pth:  30% 744M/2.47G [00:19<00:40, 42.3MB/s]
# model.safetensors:  31% 755M/2.47G [00:19<00:40, 42.5MB/s]
#
# consolidated.00.pth:  31% 755M/2.47G [00:19<00:40, 42.3MB/s]
# model.safetensors:  31% 765M/2.47G [00:19<00:40, 42.0MB/s]
#
# consolidated.00.pth:  31% 765M/2.47G [00:19<00:40, 42.3MB/s]
# model.safetensors:  31% 776M/2.47G [00:19<00:39, 42.6MB/s]
#
# consolidated.00.pth:  31% 776M/2.47G [00:19<00:40, 41.7MB/s]
# model.safetensors:  32% 786M/2.47G [00:20<00:39, 42.6MB/s]
#
# consolidated.00.pth:  32% 786M/2.47G [00:20<00:39, 42.6MB/s]
# model.safetensors:  32% 797M/2.47G [00:20<00:39, 42.3MB/s]
#
# consolidated.00.pth:  32% 797M/2.47G [00:20<00:39, 42.4MB/s]
# model.safetensors:  33% 807M/2.47G [00:20<00:39, 42.2MB/s]
#
# consolidated.00.pth:  33% 807M/2.47G [00:20<00:39, 42.7MB/s]
# model.safetensors:  33% 818M/2.47G [00:20<00:39, 42.3MB/s]
#
# consolidated.00.pth:  33% 818M/2.47G [00:20<00:38, 42.6MB/s]
# model.safetensors:  34% 828M/2.47G [00:21<00:39, 41.9MB/s]
#
# consolidated.00.pth:  34% 828M/2.47G [00:21<00:38, 42.4MB/s]
# model.safetensors:  34% 839M/2.47G [00:21<00:39, 41.7MB/s]
#
# consolidated.00.pth:  34% 839M/2.47G [00:21<00:38, 42.2MB/s]
# model.safetensors:  34% 849M/2.47G [00:21<00:39, 41.4MB/s]
# model.safetensors:  35% 860M/2.47G [00:23<02:12, 12.2MB/s]
# model.safetensors:  36% 881M/2.47G [00:24<01:19, 20.1MB/s]
#
# consolidated.00.pth:  34% 849M/2.47G [00:24<02:37, 10.3MB/s]
# model.safetensors:  36% 891M/2.47G [00:24<01:07, 23.5MB/s]
#
# consolidated.00.pth:  35% 860M/2.47G [00:24<01:57, 13.7MB/s]
#
# consolidated.00.pth:  35% 870M/2.47G [00:24<01:27, 18.3MB/s]
# model.safetensors:  36% 902M/2.47G [00:24<00:59, 26.6MB/s]
#
# consolidated.00.pth:  36% 881M/2.47G [00:24<01:10, 22.6MB/s]
# model.safetensors:  37% 912M/2.47G [00:24<00:52, 29.6MB/s]
#
# consolidated.00.pth:  36% 891M/2.47G [00:24<00:59, 26.4MB/s]
# model.safetensors:  37% 923M/2.47G [00:25<00:47, 32.4MB/s]
#
# consolidated.00.pth:  36% 902M/2.47G [00:25<00:52, 29.8MB/s]
# model.safetensors:  38% 933M/2.47G [00:25<00:44, 34.6MB/s]
#
# consolidated.00.pth:  37% 912M/2.47G [00:25<00:47, 32.8MB/s]
# model.safetensors:  38% 944M/2.47G [00:25<00:41, 36.7MB/s]
#
# consolidated.00.pth:  37% 923M/2.47G [00:25<00:43, 35.3MB/s]
# model.safetensors:  39% 954M/2.47G [00:25<00:39, 38.2MB/s]
#
# consolidated.00.pth:  38% 933M/2.47G [00:25<00:41, 37.2MB/s]
# model.safetensors:  39% 965M/2.47G [00:26<00:38, 39.5MB/s]
# model.safetensors:  39% 975M/2.47G [00:26<00:37, 40.1MB/s]
#
# consolidated.00.pth:  38% 944M/2.47G [00:26<00:46, 32.7MB/s]
#
# consolidated.00.pth:  39% 954M/2.47G [00:26<00:39, 38.5MB/s]
# model.safetensors:  40% 986M/2.47G [00:26<00:36, 41.2MB/s]
#
# consolidated.00.pth:  39% 965M/2.47G [00:26<00:34, 43.4MB/s]
# model.safetensors:  40% 996M/2.47G [00:26<00:35, 41.5MB/s]
#
# consolidated.00.pth:  39% 975M/2.47G [00:26<00:34, 43.1MB/s]
# model.safetensors:  41% 1.01G/2.47G [00:27<00:35, 41.8MB/s]
#
# consolidated.00.pth:  40% 986M/2.47G [00:27<00:34, 43.0MB/s]
# model.safetensors:  41% 1.02G/2.47G [00:27<00:34, 41.9MB/s]
#
# consolidated.00.pth:  40% 996M/2.47G [00:27<00:34, 43.0MB/s]
# model.safetensors:  42% 1.03G/2.47G [00:27<00:34, 42.3MB/s]
#
# consolidated.00.pth:  41% 1.01G/2.47G [00:27<00:34, 42.9MB/s]
# model.safetensors:  42% 1.04G/2.47G [00:27<00:33, 42.3MB/s]
#
# consolidated.00.pth:  41% 1.02G/2.47G [00:30<02:07, 11.4MB/s]
# model.safetensors:  42% 1.05G/2.47G [00:30<01:59, 12.0MB/s]
#
# consolidated.00.pth:  42% 1.04G/2.47G [00:30<01:15, 19.1MB/s]
# model.safetensors:  43% 1.07G/2.47G [00:30<01:10, 19.9MB/s]
#
# consolidated.00.pth:  42% 1.05G/2.47G [00:30<01:04, 22.1MB/s]
# model.safetensors:  44% 1.08G/2.47G [00:30<01:00, 22.9MB/s]
#
# consolidated.00.pth:  43% 1.06G/2.47G [00:30<00:55, 25.3MB/s]
# model.safetensors:  44% 1.09G/2.47G [00:30<00:52, 26.1MB/s]
#
# consolidated.00.pth:  43% 1.07G/2.47G [00:31<00:49, 28.3MB/s]
# model.safetensors:  45% 1.10G/2.47G [00:31<00:46, 29.2MB/s]
#
# consolidated.00.pth:  44% 1.08G/2.47G [00:31<00:44, 31.2MB/s]
# model.safetensors:  45% 1.11G/2.47G [00:31<00:42, 31.9MB/s]
#
# consolidated.00.pth:  44% 1.09G/2.47G [00:31<00:41, 33.6MB/s]
# model.safetensors:  45% 1.12G/2.47G [00:31<00:39, 34.2MB/s]
#
# consolidated.00.pth:  45% 1.10G/2.47G [00:31<00:38, 35.7MB/s]
# model.safetensors:  46% 1.13G/2.47G [00:31<00:37, 36.0MB/s]
#
# consolidated.00.pth:  45% 1.11G/2.47G [00:32<00:36, 37.7MB/s]
# model.safetensors:  46% 1.14G/2.47G [00:32<00:35, 37.9MB/s]
#
# consolidated.00.pth:  45% 1.12G/2.47G [00:32<00:34, 39.0MB/s]
# model.safetensors:  47% 1.15G/2.47G [00:32<00:33, 39.2MB/s]
#
# consolidated.00.pth:  46% 1.13G/2.47G [00:32<00:33, 40.0MB/s]
# model.safetensors:  47% 1.16G/2.47G [00:32<00:32, 40.3MB/s]
#
# consolidated.00.pth:  46% 1.14G/2.47G [00:32<00:32, 40.8MB/s]
# model.safetensors:  48% 1.17G/2.47G [00:32<00:32, 40.4MB/s]
#
# consolidated.00.pth:  47% 1.15G/2.47G [00:33<00:31, 41.2MB/s]
# model.safetensors:  48% 1.18G/2.47G [00:33<00:30, 41.6MB/s]
# model.safetensors:  48% 1.20G/2.47G [00:33<00:30, 42.1MB/s]
#
# consolidated.00.pth:  47% 1.16G/2.47G [00:33<00:31, 41.4MB/s]
# model.safetensors:  49% 1.21G/2.47G [00:33<00:29, 42.3MB/s]
#
# consolidated.00.pth:  48% 1.17G/2.47G [00:33<00:31, 41.6MB/s]
# model.safetensors:  49% 1.22G/2.47G [00:33<00:29, 42.4MB/s]
#
# consolidated.00.pth:  48% 1.18G/2.47G [00:33<00:30, 41.8MB/s]
# model.safetensors:  50% 1.23G/2.47G [00:34<00:29, 42.7MB/s]
#
# consolidated.00.pth:  48% 1.20G/2.47G [00:34<00:30, 42.0MB/s]
# model.safetensors:  50% 1.24G/2.47G [00:36<01:38, 12.5MB/s]
#
# consolidated.00.pth:  49% 1.21G/2.47G [00:36<01:41, 12.4MB/s]
# model.safetensors:  51% 1.26G/2.47G [00:36<00:58, 20.6MB/s]
#
# consolidated.00.pth:  50% 1.23G/2.47G [00:36<01:00, 20.6MB/s]
# model.safetensors:  51% 1.27G/2.47G [00:36<00:50, 23.7MB/s]
#
# consolidated.00.pth:  50% 1.24G/2.47G [00:36<00:52, 23.7MB/s]
# model.safetensors:  52% 1.28G/2.47G [00:37<00:44, 26.8MB/s]
#
# consolidated.00.pth:  50% 1.25G/2.47G [00:36<00:45, 26.7MB/s]
# model.safetensors:  52% 1.29G/2.47G [00:37<00:39, 29.9MB/s]
#
# consolidated.00.pth:  51% 1.26G/2.47G [00:37<00:40, 29.7MB/s]
# model.safetensors:  53% 1.30G/2.47G [00:37<00:35, 32.6MB/s]
#
# consolidated.00.pth:  51% 1.27G/2.47G [00:37<00:37, 32.5MB/s]
# model.safetensors:  53% 1.31G/2.47G [00:37<00:33, 35.0MB/s]
#
# consolidated.00.pth:  52% 1.28G/2.47G [00:37<00:34, 34.8MB/s]
# model.safetensors:  53% 1.32G/2.47G [00:38<00:31, 37.0MB/s]
#
# consolidated.00.pth:  52% 1.29G/2.47G [00:37<00:32, 36.8MB/s]
# model.safetensors:  54% 1.33G/2.47G [00:38<00:29, 38.4MB/s]
#
# consolidated.00.pth:  53% 1.30G/2.47G [00:38<00:30, 38.4MB/s]
# model.safetensors:  54% 1.34G/2.47G [00:38<00:28, 39.4MB/s]
#
# consolidated.00.pth:  53% 1.31G/2.47G [00:38<00:29, 39.5MB/s]
# model.safetensors:  55% 1.35G/2.47G [00:38<00:27, 40.5MB/s]
#
# consolidated.00.pth:  53% 1.32G/2.47G [00:38<00:28, 40.3MB/s]
# model.safetensors:  55% 1.36G/2.47G [00:39<00:26, 41.2MB/s]
#
# consolidated.00.pth:  54% 1.33G/2.47G [00:38<00:27, 41.0MB/s]
# model.safetensors:  56% 1.37G/2.47G [00:39<00:26, 41.6MB/s]
#
# consolidated.00.pth:  54% 1.34G/2.47G [00:39<00:27, 41.4MB/s]
# model.safetensors:  56% 1.38G/2.47G [00:39<00:25, 42.1MB/s]
#
# consolidated.00.pth:  55% 1.35G/2.47G [00:39<00:26, 41.8MB/s]
# model.safetensors:  56% 1.39G/2.47G [00:39<00:25, 42.1MB/s]
#
# consolidated.00.pth:  55% 1.36G/2.47G [00:39<00:26, 42.1MB/s]
# model.safetensors:  57% 1.41G/2.47G [00:40<00:25, 42.2MB/s]
#
# consolidated.00.pth:  56% 1.37G/2.47G [00:39<00:26, 41.9MB/s]
# model.safetensors:  57% 1.42G/2.47G [00:40<00:24, 42.4MB/s]
#
# consolidated.00.pth:  56% 1.38G/2.47G [00:40<00:25, 42.4MB/s]
# model.safetensors:  58% 1.43G/2.47G [00:40<00:24, 42.7MB/s]
#
# consolidated.00.pth:  56% 1.39G/2.47G [00:40<00:25, 42.6MB/s]
# model.safetensors:  58% 1.44G/2.47G [00:40<00:24, 42.6MB/s]
#
# consolidated.00.pth:  57% 1.41G/2.47G [00:40<00:25, 42.5MB/s]
# model.safetensors:  59% 1.45G/2.47G [00:41<00:24, 42.5MB/s]
#
# consolidated.00.pth:  57% 1.42G/2.47G [00:40<00:24, 42.4MB/s]
# model.safetensors:  59% 1.46G/2.47G [00:41<00:23, 42.3MB/s]
#
# consolidated.00.pth:  58% 1.43G/2.47G [00:41<00:24, 42.3MB/s]
# model.safetensors:  59% 1.47G/2.47G [00:41<00:23, 42.3MB/s]
#
# consolidated.00.pth:  58% 1.44G/2.47G [00:41<00:24, 42.4MB/s]
# model.safetensors:  60% 1.48G/2.47G [00:41<00:23, 42.5MB/s]
#
# consolidated.00.pth:  59% 1.45G/2.47G [00:41<00:24, 42.2MB/s]
# model.safetensors:  60% 1.49G/2.47G [00:42<00:24, 40.0MB/s]
#
# consolidated.00.pth:  59% 1.46G/2.47G [00:42<00:27, 37.4MB/s]
#
# consolidated.00.pth:  59% 1.47G/2.47G [00:42<00:25, 39.5MB/s]
# model.safetensors:  61% 1.50G/2.47G [00:42<00:27, 35.4MB/s]
#
# consolidated.00.pth:  60% 1.48G/2.47G [00:42<00:24, 39.7MB/s]
# model.safetensors:  61% 1.51G/2.47G [00:42<00:26, 36.8MB/s]
#
# consolidated.00.pth:  60% 1.49G/2.47G [00:42<00:24, 40.5MB/s]
# model.safetensors:  62% 1.52G/2.47G [00:42<00:24, 38.4MB/s]
#
# consolidated.00.pth:  61% 1.50G/2.47G [00:43<00:23, 41.1MB/s]
# model.safetensors:  62% 1.53G/2.47G [00:43<00:25, 36.4MB/s]
#
# consolidated.00.pth:  61% 1.51G/2.47G [00:43<00:23, 41.6MB/s]
# model.safetensors:  62% 1.54G/2.47G [00:43<00:22, 41.5MB/s]
#
# consolidated.00.pth:  62% 1.52G/2.47G [00:43<00:22, 41.8MB/s]
# model.safetensors:  63% 1.55G/2.47G [00:43<00:22, 41.8MB/s]
#
# consolidated.00.pth:  62% 1.53G/2.47G [00:43<00:22, 41.9MB/s]
# model.safetensors:  63% 1.56G/2.47G [00:43<00:21, 42.2MB/s]
#
# consolidated.00.pth:  62% 1.54G/2.47G [00:44<00:22, 41.9MB/s]
# model.safetensors:  64% 1.57G/2.47G [00:44<00:21, 42.4MB/s]
#
# consolidated.00.pth:  63% 1.55G/2.47G [00:44<00:21, 42.3MB/s]
# model.safetensors:  64% 1.58G/2.47G [00:44<00:20, 42.4MB/s]
#
# consolidated.00.pth:  63% 1.56G/2.47G [00:44<00:21, 42.5MB/s]
# model.safetensors:  64% 1.59G/2.47G [00:44<00:20, 42.4MB/s]
#
# consolidated.00.pth:  64% 1.57G/2.47G [00:44<00:21, 42.7MB/s]
# model.safetensors:  65% 1.60G/2.47G [00:44<00:20, 42.6MB/s]
#
# consolidated.00.pth:  64% 1.58G/2.47G [00:44<00:20, 42.7MB/s]
# model.safetensors:  65% 1.61G/2.47G [00:45<00:20, 42.6MB/s]
#
# consolidated.00.pth:  64% 1.59G/2.47G [00:45<00:20, 42.6MB/s]
# model.safetensors:  66% 1.63G/2.47G [00:45<00:19, 42.7MB/s]
#
# consolidated.00.pth:  65% 1.60G/2.47G [00:45<00:20, 42.7MB/s]
# model.safetensors:  66% 1.64G/2.47G [00:45<00:19, 42.7MB/s]
#
# consolidated.00.pth:  65% 1.61G/2.47G [00:45<00:20, 42.6MB/s]
# model.safetensors:  67% 1.65G/2.47G [00:45<00:19, 42.9MB/s]
#
# consolidated.00.pth:  66% 1.63G/2.47G [00:45<00:19, 42.4MB/s]
# model.safetensors:  67% 1.66G/2.47G [00:46<00:18, 42.9MB/s]
#
# consolidated.00.pth:  66% 1.64G/2.47G [00:46<00:19, 42.5MB/s]
# model.safetensors:  67% 1.67G/2.47G [00:46<00:18, 42.7MB/s]
#
# consolidated.00.pth:  67% 1.65G/2.47G [00:46<00:19, 42.2MB/s]
# model.safetensors:  68% 1.68G/2.47G [00:46<00:18, 42.6MB/s]
# model.safetensors:  68% 1.69G/2.47G [00:46<00:18, 42.6MB/s]
#
# consolidated.00.pth:  67% 1.66G/2.47G [00:46<00:20, 39.8MB/s]
# model.safetensors:  69% 1.70G/2.47G [00:47<00:18, 42.7MB/s]
#
# consolidated.00.pth:  67% 1.67G/2.47G [00:47<00:19, 40.3MB/s]
# model.safetensors:  69% 1.71G/2.47G [00:47<00:17, 42.4MB/s]
#
# consolidated.00.pth:  68% 1.68G/2.47G [00:47<00:19, 40.8MB/s]
# model.safetensors:  70% 1.72G/2.47G [00:47<00:17, 42.6MB/s]
#
# consolidated.00.pth:  68% 1.69G/2.47G [00:47<00:19, 41.1MB/s]
# model.safetensors:  70% 1.73G/2.47G [00:47<00:17, 42.4MB/s]
#
# consolidated.00.pth:  69% 1.70G/2.47G [00:47<00:18, 41.4MB/s]
# model.safetensors:  70% 1.74G/2.47G [00:48<00:17, 42.4MB/s]
#
# consolidated.00.pth:  69% 1.71G/2.47G [00:48<00:18, 41.9MB/s]
# model.safetensors:  71% 1.75G/2.47G [00:48<00:16, 42.5MB/s]
#
# consolidated.00.pth:  70% 1.72G/2.47G [00:48<00:17, 42.1MB/s]
# model.safetensors:  71% 1.76G/2.47G [00:48<00:16, 42.5MB/s]
#
# consolidated.00.pth:  70% 1.73G/2.47G [00:48<00:17, 42.4MB/s]
# model.safetensors:  72% 1.77G/2.47G [00:48<00:16, 42.5MB/s]
#
# consolidated.00.pth:  70% 1.74G/2.47G [00:48<00:17, 42.6MB/s]
# model.safetensors:  72% 1.78G/2.47G [00:49<00:16, 42.6MB/s]
#
# consolidated.00.pth:  71% 1.75G/2.47G [00:48<00:16, 42.4MB/s]
# model.safetensors:  73% 1.79G/2.47G [00:49<00:15, 42.6MB/s]
#
# consolidated.00.pth:  71% 1.76G/2.47G [00:49<00:16, 42.3MB/s]
# model.safetensors:  73% 1.80G/2.47G [00:49<00:15, 42.6MB/s]
#
# consolidated.00.pth:  72% 1.77G/2.47G [00:49<00:16, 42.2MB/s]
# model.safetensors:  73% 1.81G/2.47G [00:49<00:15, 42.8MB/s]
#
# consolidated.00.pth:  72% 1.78G/2.47G [00:49<00:16, 42.1MB/s]
# model.safetensors:  74% 1.82G/2.47G [00:50<00:15, 42.6MB/s]
#
# consolidated.00.pth:  73% 1.79G/2.47G [00:49<00:16, 41.9MB/s]
# model.safetensors:  74% 1.84G/2.47G [00:50<00:14, 42.6MB/s]
#
# consolidated.00.pth:  73% 1.80G/2.47G [00:50<00:15, 42.1MB/s]
# model.safetensors:  75% 1.85G/2.47G [00:50<00:14, 42.7MB/s]
#
# consolidated.00.pth:  73% 1.81G/2.47G [00:50<00:15, 42.0MB/s]
# model.safetensors:  75% 1.86G/2.47G [00:50<00:14, 42.7MB/s]
#
# consolidated.00.pth:  74% 1.82G/2.47G [00:50<00:15, 42.4MB/s]
# model.safetensors:  76% 1.87G/2.47G [00:51<00:14, 42.6MB/s]
#
# consolidated.00.pth:  74% 1.84G/2.47G [00:50<00:14, 42.5MB/s]
# model.safetensors:  76% 1.88G/2.47G [00:51<00:14, 42.4MB/s]
#
# consolidated.00.pth:  75% 1.85G/2.47G [00:51<00:14, 42.5MB/s]
# model.safetensors:  76% 1.89G/2.47G [00:51<00:13, 42.5MB/s]
#
# consolidated.00.pth:  75% 1.86G/2.47G [00:51<00:14, 42.5MB/s]
# model.safetensors:  77% 1.90G/2.47G [00:51<00:13, 42.6MB/s]
#
# consolidated.00.pth:  76% 1.87G/2.47G [00:51<00:14, 42.3MB/s]
# model.safetensors:  77% 1.91G/2.47G [00:52<00:13, 42.6MB/s]
#
# consolidated.00.pth:  76% 1.88G/2.47G [00:51<00:14, 42.5MB/s]
# model.safetensors:  78% 1.92G/2.47G [00:52<00:13, 42.3MB/s]
#
# consolidated.00.pth:  76% 1.89G/2.47G [00:52<00:13, 42.5MB/s]
# model.safetensors:  78% 1.93G/2.47G [00:52<00:13, 41.3MB/s]
#
# consolidated.00.pth:  77% 1.90G/2.47G [00:52<00:13, 42.0MB/s]
#
# consolidated.00.pth:  77% 1.91G/2.47G [00:52<00:13, 40.9MB/s]
# model.safetensors:  78% 1.94G/2.47G [00:52<00:14, 35.9MB/s]
#
# consolidated.00.pth:  78% 1.92G/2.47G [00:53<00:13, 40.1MB/s]
# model.safetensors:  79% 1.95G/2.47G [00:53<00:15, 33.0MB/s]
#
# consolidated.00.pth:  78% 1.93G/2.47G [00:53<00:13, 39.8MB/s]
# model.safetensors:  79% 1.96G/2.47G [00:53<00:14, 35.4MB/s]
#
# consolidated.00.pth:  78% 1.94G/2.47G [00:53<00:13, 40.3MB/s]
# model.safetensors:  80% 1.97G/2.47G [00:53<00:13, 37.3MB/s]
#
# consolidated.00.pth:  79% 1.95G/2.47G [00:53<00:12, 40.8MB/s]
# model.safetensors:  80% 1.98G/2.47G [00:54<00:12, 38.9MB/s]
#
# consolidated.00.pth:  79% 1.96G/2.47G [00:54<00:12, 41.1MB/s]
# model.safetensors:  81% 1.99G/2.47G [00:54<00:12, 39.8MB/s]
#
# consolidated.00.pth:  80% 1.97G/2.47G [00:54<00:12, 41.3MB/s]
# model.safetensors:  81% 2.00G/2.47G [00:54<00:12, 38.6MB/s]
#
# consolidated.00.pth:  80% 1.98G/2.47G [00:54<00:11, 41.5MB/s]
# model.safetensors:  81% 2.01G/2.47G [00:54<00:10, 41.7MB/s]
#
# consolidated.00.pth:  81% 1.99G/2.47G [00:54<00:11, 41.5MB/s]
# model.safetensors:  82% 2.02G/2.47G [00:55<00:10, 42.1MB/s]
#
# consolidated.00.pth:  81% 2.00G/2.47G [00:55<00:11, 41.7MB/s]
# model.safetensors:  82% 2.03G/2.47G [00:55<00:10, 42.3MB/s]
#
# consolidated.00.pth:  81% 2.01G/2.47G [00:55<00:10, 42.0MB/s]
# model.safetensors:  83% 2.04G/2.47G [00:55<00:10, 42.3MB/s]
#
# consolidated.00.pth:  82% 2.02G/2.47G [00:55<00:10, 42.1MB/s]
# model.safetensors:  83% 2.06G/2.47G [00:55<00:09, 42.5MB/s]
#
# consolidated.00.pth:  82% 2.03G/2.47G [00:55<00:10, 42.1MB/s]
# model.safetensors:  84% 2.07G/2.47G [00:56<00:09, 42.5MB/s]
#
# consolidated.00.pth:  83% 2.04G/2.47G [00:56<00:10, 42.1MB/s]
# model.safetensors:  84% 2.08G/2.47G [00:56<00:09, 42.7MB/s]
#
# consolidated.00.pth:  83% 2.06G/2.47G [00:56<00:09, 42.3MB/s]
# model.safetensors:  84% 2.09G/2.47G [00:56<00:09, 42.8MB/s]
#
# consolidated.00.pth:  84% 2.07G/2.47G [00:56<00:09, 42.3MB/s]
# model.safetensors:  85% 2.10G/2.47G [00:56<00:08, 42.8MB/s]
#
# consolidated.00.pth:  84% 2.08G/2.47G [00:56<00:09, 42.3MB/s]
# model.safetensors:  85% 2.11G/2.47G [00:57<00:08, 42.7MB/s]
#
# consolidated.00.pth:  84% 2.09G/2.47G [00:57<00:09, 42.5MB/s]
# model.safetensors:  86% 2.12G/2.47G [00:57<00:08, 42.8MB/s]
#
# consolidated.00.pth:  85% 2.10G/2.47G [00:57<00:08, 42.3MB/s]
# model.safetensors:  86% 2.13G/2.47G [00:58<00:19, 18.0MB/s]
#
# consolidated.00.pth:  85% 2.11G/2.47G [00:58<00:20, 17.6MB/s]
# model.safetensors:  87% 2.15G/2.47G [00:58<00:11, 28.3MB/s]
#
# consolidated.00.pth:  86% 2.12G/2.47G [00:58<00:15, 23.2MB/s]
#
# consolidated.00.pth:  86% 2.13G/2.47G [00:58<00:11, 29.4MB/s]
# model.safetensors:  87% 2.16G/2.47G [00:59<00:10, 31.0MB/s]
#
# consolidated.00.pth:  87% 2.14G/2.47G [00:59<00:10, 32.4MB/s]
# model.safetensors:  88% 2.17G/2.47G [00:59<00:09, 33.3MB/s]
#
# consolidated.00.pth:  87% 2.15G/2.47G [00:59<00:09, 34.8MB/s]
# model.safetensors:  88% 2.18G/2.47G [00:59<00:08, 35.3MB/s]
#
# consolidated.00.pth:  87% 2.16G/2.47G [00:59<00:08, 36.7MB/s]
# model.safetensors:  89% 2.19G/2.47G [00:59<00:07, 37.0MB/s]
#
# consolidated.00.pth:  88% 2.17G/2.47G [00:59<00:07, 38.1MB/s]
# model.safetensors:  89% 2.20G/2.47G [01:00<00:07, 38.5MB/s]
#
# consolidated.00.pth:  88% 2.18G/2.47G [01:00<00:07, 39.3MB/s]
# model.safetensors:  90% 2.21G/2.47G [01:00<00:06, 39.6MB/s]
#
# consolidated.00.pth:  89% 2.19G/2.47G [01:00<00:06, 40.2MB/s]
# model.safetensors:  90% 2.22G/2.47G [01:00<00:06, 40.5MB/s]
#
# consolidated.00.pth:  89% 2.20G/2.47G [01:00<00:06, 40.9MB/s]
# model.safetensors:  90% 2.23G/2.47G [01:00<00:05, 41.1MB/s]
#
# consolidated.00.pth:  90% 2.21G/2.47G [01:00<00:06, 41.1MB/s]
# model.safetensors:  91% 2.24G/2.47G [01:01<00:05, 41.6MB/s]
#
# consolidated.00.pth:  90% 2.22G/2.47G [01:01<00:05, 41.7MB/s]
# model.safetensors:  91% 2.25G/2.47G [01:01<00:05, 41.8MB/s]
#
# consolidated.00.pth:  90% 2.23G/2.47G [01:01<00:05, 41.9MB/s]
# model.safetensors:  92% 2.26G/2.47G [01:01<00:04, 42.2MB/s]
#
# consolidated.00.pth:  91% 2.24G/2.47G [01:01<00:05, 42.1MB/s]
# model.safetensors:  92% 2.28G/2.47G [01:01<00:04, 42.3MB/s]
#
# consolidated.00.pth:  91% 2.25G/2.47G [01:01<00:05, 42.2MB/s]
# model.safetensors:  92% 2.29G/2.47G [01:02<00:04, 42.1MB/s]
#
# consolidated.00.pth:  92% 2.26G/2.47G [01:02<00:04, 42.3MB/s]
# model.safetensors:  93% 2.30G/2.47G [01:02<00:04, 42.1MB/s]
#
# consolidated.00.pth:  92% 2.28G/2.47G [01:02<00:04, 42.6MB/s]
# model.safetensors:  93% 2.31G/2.47G [01:02<00:03, 42.2MB/s]
#
# consolidated.00.pth:  92% 2.29G/2.47G [01:02<00:04, 42.7MB/s]
# model.safetensors:  94% 2.32G/2.47G [01:02<00:03, 42.4MB/s]
# model.safetensors:  94% 2.33G/2.47G [01:03<00:03, 42.5MB/s]
#
# consolidated.00.pth:  93% 2.30G/2.47G [01:03<00:04, 36.2MB/s]
#
# consolidated.00.pth:  93% 2.31G/2.47G [01:03<00:03, 44.8MB/s]
# model.safetensors:  95% 2.34G/2.47G [01:03<00:03, 39.6MB/s]
#
# consolidated.00.pth:  94% 2.32G/2.47G [01:03<00:03, 42.4MB/s]
# model.safetensors:  95% 2.35G/2.47G [01:03<00:03, 35.4MB/s]
#
# consolidated.00.pth:  94% 2.33G/2.47G [01:03<00:03, 41.9MB/s]
# model.safetensors:  95% 2.36G/2.47G [01:04<00:03, 36.0MB/s]
#
# consolidated.00.pth:  95% 2.34G/2.47G [01:03<00:03, 42.1MB/s]
# model.safetensors:  96% 2.37G/2.47G [01:04<00:02, 37.8MB/s]
#
# consolidated.00.pth:  95% 2.35G/2.47G [01:04<00:02, 42.3MB/s]
# model.safetensors:  96% 2.38G/2.47G [01:04<00:02, 39.1MB/s]
#
# consolidated.00.pth:  95% 2.36G/2.47G [01:04<00:02, 42.5MB/s]
# model.safetensors:  97% 2.39G/2.47G [01:04<00:02, 40.2MB/s]
#
# consolidated.00.pth:  96% 2.37G/2.47G [01:04<00:02, 42.5MB/s]
# model.safetensors:  97% 2.40G/2.47G [01:04<00:01, 41.0MB/s]
#
# consolidated.00.pth:  96% 2.38G/2.47G [01:04<00:02, 42.5MB/s]
# model.safetensors:  98% 2.41G/2.47G [01:05<00:01, 41.5MB/s]
#
# consolidated.00.pth:  97% 2.39G/2.47G [01:05<00:01, 42.7MB/s]
# model.safetensors:  98% 2.42G/2.47G [01:05<00:01, 42.0MB/s]
#
# consolidated.00.pth:  97% 2.40G/2.47G [01:05<00:01, 42.5MB/s]
# model.safetensors:  98% 2.43G/2.47G [01:05<00:00, 42.1MB/s]
#
# consolidated.00.pth:  98% 2.41G/2.47G [01:05<00:01, 42.3MB/s]
# model.safetensors:  99% 2.44G/2.47G [01:05<00:00, 42.2MB/s]
#
# consolidated.00.pth:  98% 2.42G/2.47G [01:05<00:01, 42.4MB/s]
# model.safetensors:  99% 2.45G/2.47G [01:06<00:00, 42.3MB/s]
#
# consolidated.00.pth:  98% 2.43G/2.47G [01:06<00:00, 42.3MB/s]
# model.safetensors: 100% 2.46G/2.47G [01:06<00:00, 42.5MB/s]
#
# consolidated.00.pth:  99% 2.44G/2.47G [01:06<00:00, 42.3MB/s]
# model.safetensors: 100% 2.47G/2.47G [01:06<00:00, 37.5MB/s]
#
# model.safetensors: 100% 2.47G/2.47G [01:06<00:00, 37.0MB/s]
# Fetching 13 files:  54% 7/13 [01:06<00:59,  9.99s/it]
#
# consolidated.00.pth: 100% 2.46G/2.47G [01:06<00:00, 42.4MB/s]
#
# consolidated.00.pth: 100% 2.47G/2.47G [01:07<00:00, 36.9MB/s]
# Fetching 13 files: 100% 13/13 [01:07<00:00,  5.18s/it]
# Successfully downloaded model repo and wrote to the following locations:
# /content/Llama-3.2-1B-Instruct/tokenizer.json
# /content/Llama-3.2-1B-Instruct/LICENSE.txt
# /content/Llama-3.2-1B-Instruct/original
# /content/Llama-3.2-1B-Instruct/model.safetensors
# /content/Llama-3.2-1B-Instruct/README.md
# /content/Llama-3.2-1B-Instruct/USE_POLICY.md
# /content/Llama-3.2-1B-Instruct/generation_config.json
# /content/Llama-3.2-1B-Instruct/special_tokens_map.json
# /content/Llama-3.2-1B-Instruct/config.json
# /content/Llama-3.2-1B-Instruct/.gitattributes
# /content/Llama-3.2-1B-Instruct/tokenizer_config.json
# /content/Llama-3.2-1B-Instruct/.cache

# %% [markdown]
# ## Fine-tuning

# %%
config = """
# Model Arguments
model:
  _component_: torchtune.models.llama3_2.lora_llama3_2_1b
  lora_attn_modules: ['q_proj', 'v_proj', 'output_proj']
  apply_lora_to_mlp: True
  apply_lora_to_output: False
  lora_rank: 64
  lora_alpha: 128
  lora_dropout: 0.0

# Tokenizer
tokenizer:
  _component_: torchtune.models.llama3.llama3_tokenizer
  path: ./Llama-3.2-1B-Instruct/original/tokenizer.model
  max_seq_len: null

checkpointer:
  _component_: torchtune.training.FullModelHFCheckpointer
  checkpoint_dir: ./Llama-3.2-1B-Instruct
  checkpoint_files: [
    model.safetensors
  ]
  recipe_checkpoint: null
  output_dir: ./checkpoints
  model_type: LLAMA3_2
resume_from_checkpoint: False
save_adapter_weights_only: False

# Dataset and Sampler
dataset:
  _component_: torchtune.datasets.instruct_dataset
  data_files: ./train_data.json
  source: json
  split: train
seed: 42
shuffle: True
batch_size: 1
#batch_size: 4

# Optimizer and Scheduler
optimizer:
  _component_: torch.optim.AdamW
  fused: True
  weight_decay: 0.01
  lr: 3e-4
lr_scheduler:
  _component_: torchtune.modules.get_cosine_schedule_with_warmup
  num_warmup_steps: 100

loss:
  _component_: torchtune.modules.loss.CEWithChunkedOutputLoss

# Training
epochs: 4
max_steps_per_epoch: null
gradient_accumulation_steps: 4
compile: False # set it to True for better memory and performance
# compile: True # set it to True for better memory and performance

# Logging
output_dir: ./logs
metric_logger:
  _component_: torchtune.training.metric_logging.TensorBoardLogger
  log_dir: ${output_dir}
log_every_n_steps: 1
log_peak_memory_stats: False

# Environment
device: cuda
dtype: bf16

# Activations Memory
enable_activation_checkpointing: False
enable_activation_offloading: False

# Profiler (disabled)
profiler:
  _component_: torchtune.training.setup_torch_profiler
  enabled: False

  #Output directory of trace artifacts
  output_dir: ${output_dir}/profiling_outputs

  #`torch.profiler.ProfilerActivity` types to trace
  cpu: True
  cuda: True

  #trace options passed to `torch.profiler.profile`
  profile_memory: False
  with_stack: False
  record_shapes: True
  with_flops: False

  # `torch.profiler.schedule` options:
  # wait_steps -> wait, warmup_steps -> warmup, active_steps -> active, num_cycles -> repeat
  wait_steps: 5
  warmup_steps: 5
  active_steps: 2
  num_cycles: 1
"""

# %%
Path("custom_config.yaml").write_text(config)
# Out:
# 2342

# %%
# !mkdir checkpoints

# %%
# !tune run lora_finetune_single_device --config "custom_config.yaml" epochs=4
# Out:
# INFO:torchtune.utils._logging:Running LoRAFinetuneRecipeSingleDevice with resolved config:
#
# batch_size: 1
# checkpointer:
#   _component_: torchtune.training.FullModelHFCheckpointer
#   checkpoint_dir: ./Llama-3.2-1B-Instruct
#   checkpoint_files:
#   - model.safetensors
#   model_type: LLAMA3_2
#   output_dir: ./checkpoints
#   recipe_checkpoint: null
# compile: false
# dataset:
#   _component_: torchtune.datasets.instruct_dataset
#   data_files: ./train_data.json
#   source: json
#   split: train
# device: cuda
# dtype: bf16
# enable_activation_checkpointing: false
# enable_activation_offloading: false
# epochs: 4
# gradient_accumulation_steps: 4
# log_every_n_steps: 1
# log_peak_memory_stats: false
# loss:
#   _component_: torchtune.modules.loss.CEWithChunkedOutputLoss
# lr_scheduler:
#   _component_: torchtune.modules.get_cosine_schedule_with_warmup
#   num_warmup_steps: 100
# max_steps_per_epoch: null
# metric_logger:
#   _component_: torchtune.training.metric_logging.TensorBoardLogger
#   log_dir: ./logs
# model:
#   _component_: torchtune.models.llama3_2.lora_llama3_2_1b
#   apply_lora_to_mlp: true
#   apply_lora_to_output: false
#   lora_alpha: 128
#   lora_attn_modules:
#   - q_proj
#   - v_proj
#   - output_proj
#   lora_dropout: 0.0
#   lora_rank: 64
# optimizer:
#   _component_: torch.optim.AdamW
#   fused: true
#   lr: 0.0003
#   weight_decay: 0.01
# output_dir: ./logs
# profiler:
#   _component_: torchtune.training.setup_torch_profiler
#   active_steps: 2
#   cpu: true
#   cuda: true
#   enabled: false
#   num_cycles: 1
#   output_dir: ./logs/profiling_outputs
#   profile_memory: false
#   record_shapes: true
#   wait_steps: 5
#   warmup_steps: 5
#   with_flops: false
#   with_stack: false
# resume_from_checkpoint: false
# save_adapter_weights_only: false
# seed: 42
# shuffle: true
# tokenizer:
#   _component_: torchtune.models.llama3.llama3_tokenizer
#   max_seq_len: null
#   path: ./Llama-3.2-1B-Instruct/original/tokenizer.model
#
# DEBUG:torchtune.utils._logging:Setting manual seed to local seed 42. Local seed is seed + rank = 42 + 0
# 2024-12-07 19:09:58.532156: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-07 19:09:58.553197: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-07 19:09:58.559011: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-07 19:09:59.639837: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:torchtune.utils._logging:Model is initialized with precision torch.bfloat16.
# INFO:torchtune.utils._logging:Memory stats after model init:
# 	GPU peak memory allocation: 2.41 GiB
# 	GPU peak memory reserved: 2.42 GiB
# 	GPU peak memory active: 2.41 GiB
# INFO:torchtune.utils._logging:Tokenizer is initialized from file.
# INFO:torchtune.utils._logging:Optimizer and loss are initialized.
# INFO:torchtune.utils._logging:Loss is initialized.
# Generating train split: 190 examples [00:00, 2650.25 examples/s]
# INFO:torchtune.utils._logging:Dataset and Sampler are initialized.
# INFO:torchtune.utils._logging:Learning rate scheduler is initialized.
# WARNING:torchtune.utils._logging: Profiling disabled.
# INFO:torchtune.utils._logging: Profiler config after instantiation: {'enabled': False}
# 1|47|Loss: 0.056378208100795746: 100% 47/47 [07:20<00:00,  9.50s/it] INFO:torchtune.utils._logging:Starting checkpoint save...
# INFO:torchtune.utils._logging:Model checkpoint of size 2.47 GB saved to checkpoints/hf_model_0001_0.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.08 GB saved to checkpoints/adapter_0.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.08 GB saved to checkpoints/adapter_model.bin
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.00 GB saved to checkpoints/adapter_config.json
# INFO:torchtune.utils._logging:Recipe checkpoint of size 0.17 GB saved to checkpoints/recipe_state.pt
# INFO:torchtune.utils._logging:Checkpoint saved in 236.52 seconds.
#
# 1|47|Loss: 0.056378208100795746: 100% 47/47 [11:21<00:00, 14.49s/it]
#
#   2% 1/47 [00:09<07:03,  9.22s/it]
# 2|48|Loss: 0.0068580517545342445:   2% 1/47 [00:09<07:03,  9.22s/it]
# 2|48|Loss: 0.0068580517545342445:   4% 2/47 [00:18<06:55,  9.23s/it]
pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.08 GB saved to checkpoints/adapter_3.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.08 GB saved to checkpoints/adapter_model.bin
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.00 GB saved to checkpoints/adapter_config.json
# INFO:torchtune.utils._logging:Saving final epoch checkpoint.
# INFO:torchtune.utils._logging:The full model checkpoint, including all weights and configurations, has been saved successfully.You can now use this checkpoint for further training or inference.
# INFO:torchtune.utils._logging:Checkpoint saved in 158.65 seconds.
# 4|188|Loss: 0.0005777563201263547: 100% 47/47 [10:07<00:00, 12.92s/it]

# %% [markdown]
# ## Upload model

# %%
# !mkdir hf_repo

# %%
# !cp "checkpoints/hf_model_0001_3.pt" "hf_repo/pytorch_model.bin"
# !cp "checkpoints/config.json" "hf_repo/"
# !cp "Llama-3.2-1B-Instruct/original/tokenizer.model" "hf_repo/"
# !cp "Llama-3.2-1B-Instruct/generation_config.json" "hf_repo/"
# !cp "Llama-3.2-1B-Instruct/tokenizer.json" "hf_repo/"
# !cp "Llama-3.2-1B-Instruct/tokenizer_config.json" "hf_repo/"
# !cp "Llama-3.2-1B-Instruct/special_tokens_map.json" "hf_repo/"
# !cp "Llama-3.2-1B-Instruct/LICENSE.txt" "hf_repo/"
# !cp "Llama-3.2-1B-Instruct/README.md" "hf_repo/"
# !cp "Llama-3.2-1B-Instruct/USE_POLICY.md" "hf_repo/"

# %%
MODEL_PATH = "hf_repo"

tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)
model = AutoModelForCausalLM.from_pretrained(MODEL_PATH).to("cuda")

# %% [markdown]
# ## Evaluation

# %%
pipe = pipeline(
    task="text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=256,
    temperature=0.000001,
    return_full_text=False,
    model_kwargs={"torch_dtype": torch.bfloat16},
    pad_token_id=tokenizer.eos_token_id,
    device="cuda",
)

# %%
question = "What is the total premium for march 2023"
user_question = create_prompt(question)
prompt = [
    {"role": "user", "content": user_question},
]
output = pipe(prompt)
output[0]["generated_text"]
# Out:
# "{'name': 'get_metric', 'parameters': {'metric': 'get_premium', 'filters': {'starting_period': '202403', 'ending_period': '202403'}, 'groupby': none}}"

# %%
# was wrong

# %%
question = "What is the total premium by gender"
user_question = create_prompt(question)
prompt = [
    {"role": "user", "content": user_question},
]
output = pipe(prompt)
output[0]["generated_text"]
# Out:
# "{'name': 'get_metric', 'parameters': {'metric': 'get_premium', 'filters': {}, 'groupby': 'gender'}}"

# %%
# was correct

# %%
question = "What is the total premium?"
user_question = create_prompt(question)
prompt = [
    {"role": "user", "content": user_question},
]
output = pipe(prompt)
output[0]["generated_text"]
# Out:
# "{'name': 'get_metric', 'parameters': {'metric': 'get_premium', 'filters': {}, 'groupby': none}}"

# %%
question = "getme premium by membership type for first quarter"
user_question = create_prompt(question)
prompt = [
    {"role": "user", "content": user_question},
]
output = pipe(prompt)
output[0]["generated_text"]
# Out:
# "{'name': 'get_metric', 'parameters': {'metric': 'get_premium', 'filters': {'quarter': 'q1'}, 'groupby':'membership_type'}}"

# %%
question = "get me premium by membership type for female dependents for jan 2024"
user_question = create_prompt(question)
prompt = [
    {"role": "user", "content": user_question},
]
output = pipe(prompt)
output[0]["generated_text"]
# Out:
# "{'name': 'get_metric', 'parameters': {'metric': 'get_premium', 'filters': {'starting_period': '202401', 'ending_period': '202401','membership_type': 'f', 'plan_network': 'nw6'}, 'groupby':'membership_type'}}"

# %%
question = "What is the premium from jan 2023 to may 2023 for female dependents by network type"
user_question = create_prompt(question)
prompt = [
    {"role": "user", "content": user_question},
]
output = pipe(prompt)
output[0]["generated_text"]
# Out:
# "{'name': 'get_metric', 'parameters': {'metric': 'get_premium', 'filters': {'starting_period': '202301', 'ending_period': '202305', 'gender': 'f','membership_type': 'dependents'}, 'groupby': 'plan_network'}}"

# %%
# was wrong

# %%
test_data = json.loads(Path("test_data.json").read_text())

# %%
prompt = test_data[4]["input"]
print(prompt)
# Out:
# Classify the text for one of the categories:
#
# <text>
# Has anyone been able to get on disability due to just your mental illnesses? I’ve tried three times, sent in all required paperwork and have been denied every time. I have severe depression, severe social and generalized anxiety/slight agoraphobia, bipolar, autism, ptsd and ADHD. I can’t work and it’s ruining my life
# </text>
#
# Choose from one of the category:
# normal, depression, suicidal, anxiety, bipolar, stress, personality disorder
# Only choose one category, the most appropriate one. Reply only with the category.

# %%
predictions = []
for example in tqdm(test_data):
    statement = example["input"]
    prompt = [
        {"role": "user", "content": statement},
    ]
    output = pipe(prompt)
    predictions.append(output[0]["generated_text"])
# Out:
# 100%|██████████| 5052/5052 [10:29<00:00,  8.03it/s]

# %%
pd.Series(predictions).value_counts()
# Out:
# suicidal                1017
# depression               968
# normal                   968
# anxiety                  821
# stress                   549
# bipolar                  537
# personality disorder     192
# Name: count, dtype: int64

# %%
eval_df = pd.DataFrame.from_dict({"label": true_values, "prediction": predictions})
eval_df.head()
# Out:
#         label  prediction
# 0  depression    suicidal
# 1  depression  depression
# 2    suicidal    suicidal
# 3     anxiety     anxiety
# 4     bipolar     bipolar

# %%
accuracy_score(true_values, predictions)
# Out:
# 0.8489707046714172

# %%
print(classification_report(eval_df.label, eval_df.prediction))
# Out:
#                       precision    recall  f1-score   support
#
#              anxiety       0.88      0.92      0.90       787
#              bipolar       0.93      0.88      0.91       565
#           depression       0.76      0.74      0.75       988
#               normal       0.95      0.94      0.94       981
# personality disorder       0.84      0.81      0.82       200
#               stress       0.84      0.84      0.84       552
#             suicidal       0.78      0.81      0.79       979
#
#             accuracy                           0.85      5052
#            macro avg       0.85      0.85      0.85      5052
#         weighted avg       0.85      0.85      0.85      5052

# %% [markdown]
# ## References
#
# - [Trained model on HF](https://huggingface.co/curiousily/Llama-3.2-1B-Mental-Health-Sentiment)
# - [Sentiment analysis for mental health dataset](https://huggingface.co/datasets/btwitssayan/sentiment-analysis-for-mental-health)
