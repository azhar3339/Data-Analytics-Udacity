# %% [markdown]
# <a href="https://colab.research.google.com/github/azhar3339/Data-Analytics-Udacity/blob/master/22_llama_3_2_3B_fine_tuning_with_torchtune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Dec  9 19:52:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install -Uqqq pip --progress-bar off
# !pip install -qqq torchtune==0.3.1 --progress-bar off
# !pip install -qqq torchao==0.6.1 --progress-bar off
# !pip install -qqq transformers==4.46.1 --progress-bar off
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
import json
import re
from pathlib import Path
from typing import List

import numpy as np
import pandas as pd
import torch
from google.colab import userdata
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %matplotlib inline
# %config InlineBackend.figure_format='retina'


RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv("finance_training_data_v2.csv")

# %%
df.head()
# Out:
#                              Question  \
# 0  Get average contribution by gender
# 1       Get average premium by gender
# 2          Get burning cost by gender
# 3                Get claims by gender
# 4              Get exposure by gender
#
#                                               Answer
# 0  {'name': 'get_metric', 'parameters': {'metric'...
# 1  {'name': 'get_metric', 'parameters': {'metric'...
# 2  {'name': 'get_metric', 'parameters': {'metric'...
# 3  {'name': 'get_metric', 'parameters': {'metric'...
# 4  {'name': 'get_metric', 'parameters': {'metric'...

# %%
df.shape
# Out:
# (233, 2)

# %%
def create_prompt(question: str):
    prompt = """
You are an expert in composing functions. You are given a question and a set of possible functions.
Based on the question, you will need to make one or more function/tool calls to achieve the purpose.
If none of the functions can be used, point it out. If the given question lacks the parameters required by the function, also point it out. You should only return the function call in the tools call sections.
Avoid making guesses and providing speculative information, or giving incomplete responses.
All the parameters are optional, if any parameter is not required to answer the user's query, leave it empty.
If you decide to invoke any of the function(s), you MUST put it in json format like below:
{
    "name": "get_metric",
    "parameters": {
        "metric": "metric",
        "filters": {
            "provider_network": "provider_network"
        },
        "groupby": "gender"
    }
}
You SHOULD NOT include any other text in the response.

Here is a list of functions in JSON format that you can invoke:

[
    {
        "name": "get_metric",
        "description": "Retrieve specific metrics based on filters and groupings.",
        "parameters": {
            "type": "dict",
            "required": [],
            "properties": {
                "metric": {
                    "type": "string",
                    "enum": [
                        "get_premium",
                        "get_avg_contribution",
                        "get_unit_cost",
                        ...
                    ]
                },
                "filters": {
                    "type": "object",
                    "properties": {
                        "starting_period": {
                            "type": "string",
                            "description": "Starting period in YYYYMM format. Defaults to 2024 if year is not mentioned."
                        },
                        "ending_period": {
                            "type": "string",
                            "description": "Ending period in YYYYMM format. Defaults to same value as starting period if not mentioned."
                        },
                        "quarter": {
                            "type": "string",
                            "enum": ["Q1", "Q2", "Q3", "Q4"]
                        },
                        "age": {
                            "type": "integer",
                            "description": "Age of the members."
                        },
                        "gender": {
                            "type": "string",
                            "enum": ["M", "F", ""]
                        },
                        "membership_type": {
                            "type": "string",
                            "enum": ["employee", "wife", "parent", "dependent", "others", "child", ""]
                        },
                        "plan_network": {
                            "type": "string",
                            "enum": ["NW1", "NW2", "NW3", "NW4", "NW5", "NW6", "NW7", "NWS", ""]
                        },
                        "povider_network": {
                            "type": "string",
                            "enum": ["NW1", "NW2", "NW3", "NW4", "NW5", "NW6", "NW7", "NWS", ""]
                        },
                        "provider_name": {
                            "type": "string",
                            "description": "Name of the provider."
                        },
                        "provider_region": {
                            "type": "string",
                            "enum": ["eastern", "western", "central", "northern", "southern", ""]
                        },
                        "benefit_type": {
                            "type": "string",
                            "enum": ["chronic", "standard", "dental", ""]
                        },
                        "claims_type": {
                            "type": "string",
                            "enum": ["I", "O", ""],
                            "description": "I for Inpatient claims, O for Outpatient claims."
                        }
                    }
                },
                "groupby": {
                    "type": "string",
                    "description": "One of the above filters to group the results by."
                }
            }
        }
    }
]

Question:
""".strip()
    return prompt + question

# %%
def create_dataset(df):
    rows = []
    for _, row in tqdm(df.iterrows()):
        rows.append(
            {
                "input": create_prompt(row.Question),
                "output": row.Answer.lower(),
            }
        )
    return rows

# %%
train_rows = create_dataset(df)
# Out:
# 233it [00:00, 13831.03it/s]

# %%
Path("train_data.json").write_text(json.dumps(train_rows))
# Out:
# 1161758

# %% [markdown]
# ## Download Model

# %%
hf_token = userdata.get("HF_TOKEN")

# %%
# !tune download "meta-llama/Llama-3.2-3B-Instruct" \
  --output-dir "./Llama-3.2-3B-Instruct" \
  --hf-token "{hf_token}" \
  --ignore-patterns "[]"
# Out:
# Ignoring files matching the following patterns: []
# Fetching 16 files:   0% 0/16 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0% 0.00/1.46G [00:00<?, ?B/s]
#
# model-00001-of-00002.safetensors:   0% 0.00/4.97G [00:00<?, ?B/s]
#
#
# .gitattributes: 100% 1.52k/1.52k [00:00<00:00, 9.21MB/s]
# Fetching 16 files:   6% 1/16 [00:00<00:03,  4.62it/s]
#
#
# config.json: 100% 878/878 [00:00<00:00, 7.16MB/s]
#
#
#
# generation_config.json: 100% 189/189 [00:00<00:00, 1.16MB/s]
#
#
#
# model.safetensors.index.json: 100% 20.9k/20.9k [00:00<00:00, 74.4MB/s]
#
#
#
# consolidated.00.pth:   0% 0.00/6.43G [00:00<?, ?B/s]
#
#
#
# USE_POLICY.md: 100% 6.02k/6.02k [00:00<00:00, 30.0MB/s]
# Fetching 16 files:  25% 4/16 [00:00<00:00, 12.68it/s]
#
#
#
# tokenizer.model:   0% 0.00/2.18M [00:00<?, ?B/s]
#
#
#
#
# original/orig_params.json: 100% 220/220 [00:00<00:00, 1.46MB/s]
#
#
#
#
#
# original/params.json: 100% 220/220 [00:00<00:00, 1.76MB/s]
#
#
#
#
#
# special_tokens_map.json: 100% 296/296 [00:00<00:00, 2.44MB/s]
# tokenizer.model: 100% 2.18M/2.18M [00:00<00:00, 37.0MB/s]
#
# model-00002-of-00002.safetensors:   1% 10.5M/1.46G [00:00<00:35, 40.4MB/s]
#
# model-00001-of-00002.safetensors:   0% 10.5M/4.97G [00:00<02:00, 41.1MB/s]
#
#
#
# tokenizer.json:   0% 0.00/9.09M [00:00<?, ?B/s]
#
#
# consolidated.00.pth:   0% 10.5M/6.43G [00:00<02:41, 39.8MB/s]
#
#
#
#
# tokenizer_config.json: 100% 54.5k/54.5k [00:00<00:00, 8.29MB/s]
#
# model-00002-of-00002.safetensors:   1% 21.0M/1.46G [00:00<00:34, 41.6MB/s]
#
# model-00001-of-00002.safetensors:   0% 21.0M/4.97G [00:00<01:57, 42.0MB/s]
#
#
# consolidated.00.pth:   0% 21.0M/6.43G [00:00<02:34, 41.5MB/s]
# model-00002-of-00002.safetensors:   2% 31.5M/1.46G [00:00<00:33, 42.3MB/s]
#
# model-00001-of-00002.safetensors:   1% 31.5M/4.97G [00:00<01:55, 42.7MB/s]
#
#
#
# tokenizer.json: 100% 9.09M/9.09M [00:00<00:00, 19.9MB/s]
#
#
#
# consolidated.00.pth:   0% 31.5M/6.43G [00:00<02:30, 42.4MB/s]
# model-00002-of-00002.safetensors:   3% 41.9M/1.46G [00:00<00:33, 42.7MB/s]
#
# model-00001-of-00002.safetensors:   1% 41.9M/4.97G [00:00<01:55, 42.8MB/s]
#
#
# consolidated.00.pth:   1% 41.9M/6.43G [00:00<02:30, 42.3MB/s]
# model-00002-of-00002.safetensors:   4% 52.4M/1.46G [00:01<00:32, 42.8MB/s]
#
# model-00001-of-00002.safetensors:   1% 52.4M/4.97G [00:01<01:54, 42.8MB/s]
#
#
# consolidated.00.pth:   1% 52.4M/6.43G [00:01<02:29, 42.5MB/s]
# model-00002-of-00002.safetensors:   4% 62.9M/1.46G [00:01<00:32, 42.9MB/s]
#
# model-00001-of-00002.safetensors:   1% 62.9M/4.97G [00:01<01:54, 42.9MB/s]
#
#
# consolidated.00.pth:   1% 62.9M/6.43G [00:01<02:28, 42.7MB/s]
# model-00002-of-00002.safetensors:   5% 73.4M/1.46G [00:01<00:32, 42.9MB/s]
#
# model-00001-of-00002.safetensors:   1% 73.4M/4.97G [00:01<01:54, 42.8MB/s]
#
#
# consolidated.00.pth:   1% 73.4M/6.43G [00:01<02:29, 42.4MB/s]
# model-00002-of-00002.safetensors:   6% 83.9M/1.46G [00:01<00:32, 42.8MB/s]
#
# model-00001-of-00002.safetensors:   2% 83.9M/4.97G [00:01<01:54, 42.5MB/s]
#
#
# consolidated.00.pth:   1% 83.9M/6.43G [00:01<02:29, 42.3MB/s]
# model-00002-of-00002.safetensors:   6% 94.4M/1.46G [00:02<00:31, 42.9MB/s]
#
# model-00001-of-00002.safetensors:   2% 94.4M/4.97G [00:02<01:54, 42.5MB/s]
#
#
# consolidated.00.pth:   1% 94.4M/6.43G [00:02<02:28, 42.5MB/s]
# model-00002-of-00002.safetensors:   7% 105M/1.46G [00:02<00:31, 43.0MB/s]
#
# model-00001-of-00002.safetensors:   2% 105M/4.97G [00:02<01:53, 42.7MB/s]
#
#
# consolidated.00.pth:   2% 105M/6.43G [00:04<09:59, 10.5MB/s]
# model-00002-of-00002.safetensors:   8% 115M/1.46G [00:05<02:18, 9.70MB/s]
#
# model-00001-of-00002.safetensors:   2% 115M/4.97G [00:05<08:17, 9.75MB/s]
#
#
# consolidated.00.pth:   2% 115M/6.43G [00:05<08:11, 12.8MB/s]
#
#
# consolidated.00.pth:   2% 136M/6.43G [00:05<04:58, 21.1MB/s]
# model-00002-of-00002.safetensors:   9% 136M/1.46G [00:05<01:21, 16.2MB/s]
#
# model-00001-of-00002.safetensors:   3% 136M/4.97G [00:05<04:56, 16.3MB/s]
#
#
# consolidated.00.pth:   2% 147M/6.43G [00:05<04:19, 24.2MB/s]
# model-00002-of-00002.safetensors:  10% 147M/1.46G [00:05<01:08, 19.2MB/s]
#
# model-00001-of-00002.safetensors:   3% 147M/4.97G [00:05<04:10, 19.2MB/s]
#
#
# consolidated.00.pth:   2% 157M/6.43G [00:06<03:49, 27.3MB/s]
# model-00002-of-00002.safetensors:  11% 157M/1.46G [00:06<00:58, 22.4MB/s]
#
# model-00001-of-00002.safetensors:   3% 157M/4.97G [00:06<03:33, 22.5MB/s]
#
#
# consolidated.00.pth:   3% 168M/6.43G [00:06<03:26, 30.2MB/s]
# model-00002-of-00002.safetensors:  11% 168M/1.46G [00:06<00:50, 25.8MB/s]
#
# model-00001-of-00002.safetensors:   3% 168M/4.97G [00:06<03:05, 25.8MB/s]
#
#
# consolidated.00.pth:   3% 178M/6.43G [00:06<03:09, 32.9MB/s]
# model-00002-of-00002.safetensors:  12% 178M/1.46G [00:06<00:44, 29.0MB/s]
#
# model-00001-of-00002.safetensors:   4% 178M/4.97G [00:06<02:44, 29.1MB/s]
#
#
# consolidated.00.pth:   3% 189M/6.43G [00:06<02:57, 35.2MB/s]
# model-00002-of-00002.safetensors:  13% 189M/1.46G [00:06<00:39, 32.0MB/s]
#
# model-00001-of-00002.safetensors:   4% 189M/4.97G [00:06<02:29, 31.9MB/s]
#
#
# consolidated.00.pth:   3% 199M/6.43G [00:07<02:48, 36.9MB/s]
# model-00002-of-00002.safetensors:  14% 199M/1.46G [00:07<00:36, 34.6MB/s]
#
# model-00001-of-00002.safetensors:   4% 199M/4.97G [00:07<02:18, 34.5MB/s]
#
#
# consolidated.00.pth:   3% 210M/6.43G [00:07<02:42, 38.3MB/s]
# model-00002-of-00002.safetensors:  14% 210M/1.46G [00:07<00:34, 36.7MB/s]
#
# model-00001-of-00002.safetensors:   4% 210M/4.97G [00:07<02:10, 36.3MB/s]
#
#
# consolidated.00.pth:   3% 220M/6.43G [00:07<02:37, 39.4MB/s]
# model-00002-of-00002.safetensors:  15% 220M/1.46G [00:07<00:32, 38.3MB/s]
#
# model-00001-of-00002.safetensors:   4% 220M/4.97G [00:07<02:06, 37.7MB/s]
#
#
# consolidated.00.pth:   4% 231M/6.43G [00:07<02:33, 40.5MB/s]
# model-00002-of-00002.safetensors:  16% 231M/1.46G [00:07<00:31, 39.6MB/s]
#
# model-00001-of-00002.safetensors:   5% 231M/4.97G [00:07<02:00, 39.2MB/s]
#
#
# consolidated.00.pth:   4% 241M/6.43G [00:08<02:31, 40.9MB/s]
# model-00002-of-00002.safetensors:  17% 241M/1.46G [00:08<00:29, 40.6MB/s]
#
# model-00001-of-00002.safetensors:   5% 241M/4.97G [00:08<01:57, 40.1MB/s]
# model-00002-of-00002.safetensors:  17% 252M/1.46G [00:08<00:29, 41.3MB/s]
#
#
# consolidated.00.pth:   4% 252M/6.43G [00:08<02:29, 41.2MB/s]
#
# model-00001-of-00002.safetensors:   5% 252M/4.97G [00:08<01:55, 40.9MB/s]
# model-00002-of-00002.safetensors:  18% 262M/1.46G [00:08<00:28, 41.8MB/s]
#
#
# consolidated.00.pth:   4% 262M/6.43G [00:08<02:27, 41.7MB/s]
#
# model-00001-of-00002.safetensors:   5% 262M/4.97G [00:08<01:53, 41.4MB/s]
# model-00002-of-00002.safetensors:  19% 273M/1.46G [00:08<00:28, 42.3MB/s]
#
#
# consolidated.00.pth:   4% 273M/6.43G [00:08<02:27, 41.8MB/s]
#
# model-00001-of-00002.safetensors:   5% 273M/4.97G [00:08<01:52, 41.6MB/s]
# model-00002-of-00002.safetensors:  19% 283M/1.46G [00:09<00:27, 42.5MB/s]
#
#
# consolidated.00.pth:   4% 283M/6.43G [00:09<02:25, 42.2MB/s]
#
# model-00001-of-00002.safetensors:   6% 283M/4.97G [00:09<01:51, 42.0MB/s]
# model-00002-of-00002.safetensors:  20% 294M/1.46G [00:09<00:27, 42.7MB/s]
#
#
# consolidated.00.pth:   5% 294M/6.43G [00:09<02:24, 42.5MB/s]
#
# model-00001-of-00002.safetensors:   6% 294M/4.97G [00:09<01:51, 42.1MB/s]
# model-00002-of-00002.safetensors:  21% 304M/1.46G [00:09<00:26, 42.8MB/s]
#
#
# consolidated.00.pth:   5% 304M/6.43G [00:09<02:24, 42.3MB/s]
#
# model-00001-of-00002.safetensors:   6% 304M/4.97G [00:09<01:50, 42.1MB/s]
# model-00002-of-00002.safetensors:  22% 315M/1.46G [00:09<00:26, 42.7MB/s]
#
#
# consolidated.00.pth:   5% 315M/6.43G [00:09<02:24, 42.3MB/s]
#
# model-00001-of-00002.safetensors:   6% 315M/4.97G [00:09<01:49, 42.3MB/s]
#
#
# consolidated.00.pth:   5% 325M/6.43G [00:10<02:24, 42.3MB/s]
#
# model-00001-of-00002.safetensors:   7% 325M/4.97G [00:10<01:49, 42.5MB/s]
# model-00002-of-00002.safetensors:  22% 325M/1.46G [00:10<00:28, 39.5MB/s]
#
#
# consolidated.00.pth:   5% 336M/6.43G [00:10<02:23, 42.5MB/s]
#
# model-00001-of-00002.safetensors:   7% 336M/4.97G [00:10<01:49, 42.5MB/s]
# model-00002-of-00002.safetensors:  23% 336M/1.46G [00:10<00:27, 40.4MB/s]
#
#
# consolidated.00.pth:   5% 346M/6.43G [00:10<02:23, 42.5MB/s]
#
# model-00001-of-00002.safetensors:   7% 346M/4.97G [00:10<01:48, 42.5MB/s]
# model-00002-of-00002.safetensors:  24% 346M/1.46G [00:10<00:27, 41.1MB/s]
#
#
# consolidated.00.pth:   6% 357M/6.43G [00:10<02:22, 42.7MB/s]
#
# model-00001-of-00002.safetensors:   7% 357M/4.97G [00:10<01:48, 42.5MB/s]
# model-00002-of-00002.safetensors:  24% 357M/1.46G [00:10<00:26, 41.4MB/s]
#
#
# consolidated.00.pth:   6% 367M/6.43G [00:10<02:21, 42.8MB/s]
#
# model-00001-of-00002.safetensors:   7% 367M/4.97G [00:11<01:48, 42.6MB/s]
# model-00002-of-00002.safetensors:  25% 367M/1.46G [00:11<00:26, 41.7MB/s]
#
#
# consolidated.00.pth:   6% 377M/6.43G [00:11<02:22, 42.4MB/s]
#
# model-00001-of-00002.safetensors:   8% 377M/4.97G [00:11<01:47, 42.5MB/s]
# model-00002-of-00002.safetensors:  26% 377M/1.46G [00:11<00:25, 42.0MB/s]
#
#
# consolidated.00.pth:   6% 388M/6.43G [00:11<02:21, 42.5MB/s]
#
# model-00001-of-00002.safetensors:   8% 388M/4.97G [00:11<01:47, 42.7MB/s]
# model-00002-of-00002.safetensors:  27% 388M/1.46G [00:11<00:29, 36.0MB/s]
#
#
# consolidated.00.pth:   6% 398M/6.43G [00:11<02:21, 42.5MB/s]
#
# model-00001-of-00002.safetensors:   8% 398M/4.97G [00:11<01:47, 42.7MB/s]
#
#
# consolidated.00.pth:   6% 409M/6.43G [00:11<02:21, 42.6MB/s]
#
# model-00001-of-00002.safetensors:   8% 409M/4.97G [00:12<01:47, 42.5MB/s]
# model-00002-of-00002.safetensors:  28% 409M/1.46G [00:12<00:23, 44.4MB/s]
#
#
# consolidated.00.pth:   7% 419M/6.43G [00:12<02:20, 42.7MB/s]
#
# model-00001-of-00002.safetensors:   8% 419M/4.97G [00:12<01:46, 42.5MB/s]
# model-00002-of-00002.safetensors:  29% 419M/1.46G [00:12<00:23, 44.1MB/s]
#
#
# consolidated.00.pth:   7% 430M/6.43G [00:12<02:20, 42.6MB/s]
#
# model-00001-of-00002.safetensors:   9% 430M/4.97G [00:12<01:47, 42.4MB/s]
# model-00002-of-00002.safetensors:  29% 430M/1.46G [00:12<00:23, 43.8MB/s]
#
#
# consolidated.00.pth:   7% 440M/6.43G [00:12<02:21, 42.3MB/s]
# model-00002-of-00002.safetensors:  30% 440M/1.46G [00:13<00:45, 22.2MB/s]
#
# model-00001-of-00002.safetensors:   9% 440M/4.97G [00:14<05:18, 14.2MB/s]
# model-00002-of-00002.safetensors:  31% 451M/1.46G [00:15<01:25, 11.8MB/s]
#
# model-00001-of-00002.safetensors:   9% 451M/4.97G [00:15<06:16, 12.0MB/s]
#
#
# consolidated.00.pth:   7% 451M/6.43G [00:15<10:23, 9.58MB/s]
# model-00002-of-00002.safetensors:  32% 472M/1.46G [00:15<00:51, 19.2MB/s]
#
# model-00001-of-00002.safetensors:  10% 472M/4.97G [00:15<03:47, 19.8MB/s]
#
#
# consolidated.00.pth:   7% 461M/6.43G [00:15<07:41, 12.9MB/s]
# model-00002-of-00002.safetensors:  33% 482M/1.46G [00:16<00:44, 22.1MB/s]
#
#
# consolidated.00.pth:   7% 472M/6.43G [00:16<05:44, 17.3MB/s]
#
# model-00001-of-00002.safetensors:  10% 482M/4.97G [00:16<03:17, 22.7MB/s]
# model-00002-of-00002.safetensors:  34% 493M/1.46G [00:16<00:38, 25.3MB/s]
#
#
# consolidated.00.pth:   8% 482M/6.43G [00:16<04:42, 21.0MB/s]
#
# model-00001-of-00002.safetensors:  10% 493M/4.97G [00:16<02:52, 25.9MB/s]
# model-00002-of-00002.safetensors:  34% 503M/1.46G [00:16<00:33, 28.3MB/s]
#
#
# consolidated.00.pth:   8% 493M/6.43G [00:16<03:59, 24.7MB/s]
#
# model-00001-of-00002.safetensors:  10% 503M/4.97G [00:16<02:33, 29.0MB/s]
# model-00002-of-00002.safetensors:  35% 514M/1.46G [00:16<00:30, 31.2MB/s]
#
#
# consolidated.00.pth:   8% 503M/6.43G [00:16<03:29, 28.2MB/s]
#
# model-00001-of-00002.safetensors:  10% 514M/4.97G [00:16<02:19, 31.9MB/s]
# model-00002-of-00002.safetensors:  36% 524M/1.46G [00:17<00:27, 33.9MB/s]
#
#
# consolidated.00.pth:   8% 514M/6.43G [00:17<03:08, 31.4MB/s]
#
# model-00001-of-00002.safetensors:  11% 524M/4.97G [00:17<02:09, 34.4MB/s]
# model-00002-of-00002.safetensors:  37% 535M/1.46G [00:17<00:25, 36.0MB/s]
#
#
# consolidated.00.pth:   8% 524M/6.43G [00:17<02:53, 34.1MB/s]
#
# model-00001-of-00002.safetensors:  11% 535M/4.97G [00:17<02:01, 36.4MB/s]
# model-00002-of-00002.safetensors:  37% 545M/1.46G [00:17<00:24, 37.5MB/s]
#
#
# consolidated.00.pth:   8% 535M/6.43G [00:17<02:43, 36.0MB/s]
#
# model-00001-of-00002.safetensors:  11% 545M/4.97G [00:17<01:56, 38.1MB/s]
# model-00002-of-00002.safetensors:  38% 556M/1.46G [00:17<00:23, 38.7MB/s]
#
# model-00001-of-00002.safetensors:  11% 556M/4.97G [00:17<01:51, 39.4MB/s]
#
#
# consolidated.00.pth:   8% 545M/6.43G [00:17<02:36, 37.6MB/s]
# model-00002-of-00002.safetensors:  39% 566M/1.46G [00:18<00:22, 39.9MB/s]
#
# model-00001-of-00002.safetensors:  11% 566M/4.97G [00:18<01:49, 40.2MB/s]
#
#
# consolidated.00.pth:   9% 556M/6.43G [00:18<02:31, 38.8MB/s]
# model-00002-of-00002.safetensors:  40% 577M/1.46G [00:18<00:21, 40.8MB/s]
#
# model-00001-of-00002.safetensors:  12% 577M/4.97G [00:18<01:47, 40.9MB/s]
#
#
# consolidated.00.pth:   9% 566M/6.43G [00:18<02:26, 39.9MB/s]
# model-00002-of-00002.safetensors:  40% 587M/1.46G [00:18<00:21, 41.2MB/s]
#
#
# consolidated.00.pth:   9% 577M/6.43G [00:18<02:52, 33.9MB/s]
# model-00002-of-00002.safetensors:  41% 598M/1.46G [00:18<00:20, 41.6MB/s]
#
# model-00001-of-00002.safetensors:  12% 587M/4.97G [00:18<02:11, 33.2MB/s]
#
#
# consolidated.00.pth:   9% 587M/6.43G [00:18<02:19, 41.9MB/s]
#
# model-00001-of-00002.safetensors:  12% 598M/4.97G [00:19<01:48, 40.2MB/s]
# model-00002-of-00002.safetensors:  42% 608M/1.46G [00:19<00:20, 41.7MB/s]
#
#
# consolidated.00.pth:   9% 598M/6.43G [00:19<02:11, 44.5MB/s]
#
# model-00001-of-00002.safetensors:  12% 608M/4.97G [00:19<01:35, 45.7MB/s]
# model-00002-of-00002.safetensors:  42% 619M/1.46G [00:19<00:20, 41.7MB/s]
#
# model-00001-of-00002.safetensors:  12% 619M/4.97G [00:19<01:36, 44.9MB/s]
#
#
# consolidated.00.pth:   9% 608M/6.43G [00:19<02:13, 43.6MB/s]
# model-00002-of-00002.safetensors:  43% 629M/1.46G [00:19<00:19, 42.0MB/s]
#
#
# consolidated.00.pth:  10% 619M/6.43G [00:19<02:14, 43.2MB/s]
#
# Fetching 16 files:  25% 4/16 [00:19<00:00, 12.68it/s]
# model-00002-of-00002.safetensors:  44% 640M/1.46G [00:19<00:19, 42.3MB/s]
#
#
# consolidated.00.pth:  10% 629M/6.43G [00:19<02:15, 42.9MB/s]
#
# model-00001-of-00002.safetensors:  13% 640M/4.97G [00:20<02:02, 35.3MB/s]
#
#
# consolidated.00.pth:  10% 640M/6.43G [00:20<02:15, 42.7MB/s]
# model-00002-of-00002.safetensors:  45% 650M/1.46G [00:20<00:21, 38.2MB/s]
#
# model-00001-of-00002.safetensors:  13% 661M/4.97G [00:20<01:34, 45.7MB/s]
#
#
# consolidated.00.pth:  10% 650M/6.43G [00:20<02:16, 42.4MB/s]
# model-00002-of-00002.safetensors:  45% 661M/1.46G [00:20<00:20, 39.5MB/s]
#
# model-00001-of-00002.safetensors:  14% 671M/4.97G [00:20<01:35, 44.8MB/s]
#
#
# consolidated.00.pth:  10% 661M/6.43G [00:20<02:16, 42.2MB/s]
# model-00002-of-00002.safetensors:  46% 671M/1.46G [00:20<00:19, 40.3MB/s]
#
# model-00001-of-00002.safetensors:  14% 682M/4.97G [00:20<01:36, 44.3MB/s]
#
#
# consolidated.00.pth:  10% 671M/6.43G [00:20<02:16, 42.2MB/s]
# model-00002-of-00002.safetensors:  47% 682M/1.46G [00:20<00:19, 40.9MB/s]
#
# model-00001-of-00002.safetensors:  14% 692M/4.97G [00:21<01:37, 43.7MB/s]
#
#
# consolidated.00.pth:  11% 682M/6.43G [00:21<02:16, 42.1MB/s]
# model-00002-of-00002.safetensors:  47% 692M/1.46G [00:21<00:18, 41.4MB/s]
#
# model-00001-of-00002.safetensors:  14% 703M/4.97G [00:21<01:38, 43.4MB/s]
#
#
# consolidated.00.pth:  11% 692M/6.43G [00:21<02:15, 42.2MB/s]
# model-00002-of-00002.safetensors:  48% 703M/1.46G [00:21<00:18, 41.2MB/s]
#
# model-00001-of-00002.safetensors:  14% 713M/4.97G [00:21<01:37, 43.5MB/s]
#
#
# consolidated.00.pth:  11% 703M/6.43G [00:21<02:15, 42.3MB/s]
# model-00002-of-00002.safetensors:  49% 713M/1.46G [00:21<00:17, 41.7MB/s]
#
# model-00001-of-00002.safetensors:  15% 724M/4.97G [00:21<01:38, 43.2MB/s]
#
#
# consolidated.00.pth:  11% 713M/6.43G [00:21<02:14, 42.5MB/s]
# model-00002-of-00002.safetensors:  50% 724M/1.46G [00:21<00:17, 42.1MB/s]
#
# model-00001-of-00002.safetensors:  15% 734M/4.97G [00:22<01:38, 43.1MB/s]
#
#
# consolidated.00.pth:  11% 724M/6.43G [00:22<02:13, 42.7MB/s]
# model-00002-of-00002.safetensors:  50% 734M/1.46G [00:22<00:17, 42.3MB/s]
#
# model-00001-of-00002.safetensors:  15% 744M/4.97G [00:22<01:38, 42.7MB/s]
#
#
# consolidated.00.pth:  11% 734M/6.43G [00:22<02:13, 42.7MB/s]
# model-00002-of-00002.safetensors:  51% 744M/1.46G [00:22<00:16, 42.3MB/s]
#
# model-00001-of-00002.safetensors:  15% 755M/4.97G [00:22<01:39, 42.5MB/s]
#
#
# consolidated.00.pth:  12% 744M/6.43G [00:22<02:13, 42.6MB/s]
# model-00002-of-00002.safetensors:  52% 755M/1.46G [00:22<00:16, 42.5MB/s]
#
# model-00001-of-00002.safetensors:  15% 765M/4.97G [00:22<01:38, 42.6MB/s]
# model-00002-of-00002.safetensors:  52% 765M/1.46G [00:23<00:32, 21.4MB/s]
#
#
# consolidated.00.pth:  12% 755M/6.43G [00:23<04:50, 19.5MB/s]
#
# model-00001-of-00002.safetensors:  16% 776M/4.97G [00:23<03:21, 20.8MB/s]
# model-00002-of-00002.safetensors:  54% 786M/1.46G [00:25<00:49, 13.7MB/s]
#
# model-00001-of-00002.safetensors:  16% 786M/4.97G [00:25<06:14, 11.2MB/s]
#
#
# consolidated.00.pth:  12% 765M/6.43G [00:25<09:03, 10.4MB/s]
#
# model-00001-of-00002.safetensors:  16% 797M/4.97G [00:26<04:35, 15.2MB/s]
# model-00002-of-00002.safetensors:  55% 807M/1.46G [00:26<00:31, 20.6MB/s]
#
# model-00001-of-00002.safetensors:  16% 807M/4.97G [00:26<03:29, 19.9MB/s]
#
#
# consolidated.00.pth:  12% 786M/6.43G [00:26<05:23, 17.4MB/s]
# model-00002-of-00002.safetensors:  56% 818M/1.46G [00:26<00:27, 23.3MB/s]
#
# model-00001-of-00002.safetensors:  16% 818M/4.97G [00:26<02:55, 23.6MB/s]
#
#
# consolidated.00.pth:  12% 797M/6.43G [00:26<04:35, 20.4MB/s]
# model-00002-of-00002.safetensors:  57% 828M/1.46G [00:26<00:24, 26.0MB/s]
#
# model-00001-of-00002.safetensors:  17% 828M/4.97G [00:26<02:31, 27.3MB/s]
#
#
# consolidated.00.pth:  13% 807M/6.43G [00:26<03:58, 23.6MB/s]
# model-00002-of-00002.safetensors:  57% 839M/1.46G [00:26<00:21, 28.9MB/s]
#
# model-00001-of-00002.safetensors:  17% 839M/4.97G [00:26<02:14, 30.6MB/s]
#
#
# consolidated.00.pth:  13% 818M/6.43G [00:26<03:29, 26.7MB/s]
# model-00002-of-00002.safetensors:  58% 849M/1.46G [00:27<00:19, 31.6MB/s]
#
# model-00001-of-00002.safetensors:  17% 849M/4.97G [00:27<02:05, 32.9MB/s]
#
#
# consolidated.00.pth:  13% 828M/6.43G [00:27<03:07, 29.9MB/s]
# model-00002-of-00002.safetensors:  59% 860M/1.46G [00:27<00:17, 34.1MB/s]
#
# model-00001-of-00002.safetensors:  17% 860M/4.97G [00:27<01:56, 35.4MB/s]
#
#
# consolidated.00.pth:  13% 839M/6.43G [00:27<02:51, 32.7MB/s]
# model-00002-of-00002.safetensors:  60% 870M/1.46G [00:27<00:16, 36.0MB/s]
#
# model-00001-of-00002.safetensors:  18% 870M/4.97G [00:27<01:50, 37.1MB/s]
#
#
# consolidated.00.pth:  13% 849M/6.43G [00:27<02:39, 35.0MB/s]
# model-00002-of-00002.safetensors:  60% 881M/1.46G [00:27<00:15, 37.7MB/s]
#
# model-00001-of-00002.safetensors:  18% 881M/4.97G [00:27<01:45, 38.6MB/s]
#
#
# consolidated.00.pth:  13% 860M/6.43G [00:27<02:30, 36.9MB/s]
# model-00002-of-00002.safetensors:  61% 891M/1.46G [00:28<00:14, 39.0MB/s]
#
# model-00001-of-00002.safetensors:  18% 891M/4.97G [00:28<01:42, 39.9MB/s]
#
#
# consolidated.00.pth:  14% 870M/6.43G [00:28<02:26, 38.0MB/s]
# model-00002-of-00002.safetensors:  62% 902M/1.46G [00:28<00:13, 39.9MB/s]
#
# model-00001-of-00002.safetensors:  18% 902M/4.97G [00:28<01:40, 40.4MB/s]
#
#
# consolidated.00.pth:  14% 881M/6.43G [00:28<02:21, 39.2MB/s]
# model-00002-of-00002.safetensors:  62% 912M/1.46G [00:28<00:13, 40.7MB/s]
#
# model-00001-of-00002.safetensors:  18% 912M/4.97G [00:28<01:38, 41.2MB/s]
#
#
# consolidated.00.pth:  14% 891M/6.43G [00:28<02:17, 40.2MB/s]
# model-00002-of-00002.safetensors:  63% 923M/1.46G [00:28<00:13, 41.2MB/s]
#
# model-00001-of-00002.safetensors:  19% 923M/4.97G [00:28<01:37, 41.6MB/s]
#
#
# consolidated.00.pth:  14% 902M/6.43G [00:28<02:15, 40.8MB/s]
# model-00002-of-00002.safetensors:  64% 933M/1.46G [00:29<00:12, 41.6MB/s]
#
# model-00001-of-00002.safetensors:  19% 933M/4.97G [00:29<01:36, 41.7MB/s]
# model-00002-of-00002.safetensors:  65% 944M/1.46G [00:29<00:12, 41.8MB/s]
#
#
# consolidated.00.pth:  14% 912M/6.43G [00:29<02:44, 33.5MB/s]
#
# model-00001-of-00002.safetensors:  19% 944M/4.97G [00:29<01:36, 41.7MB/s]
#
#
# consolidated.00.pth:  14% 923M/6.43G [00:29<02:14, 40.8MB/s]
# model-00002-of-00002.safetensors:  65% 954M/1.46G [00:29<00:12, 42.0MB/s]
#
# model-00001-of-00002.safetensors:  19% 954M/4.97G [00:29<01:35, 41.8MB/s]
#
#
# consolidated.00.pth:  15% 933M/6.43G [00:29<02:01, 45.3MB/s]
# model-00002-of-00002.safetensors:  66% 965M/1.46G [00:29<00:11, 42.2MB/s]
#
# model-00001-of-00002.safetensors:  19% 965M/4.97G [00:29<01:34, 42.1MB/s]
#
#
# consolidated.00.pth:  15% 944M/6.43G [00:29<02:02, 44.8MB/s]
# model-00002-of-00002.safetensors:  67% 975M/1.46G [00:30<00:11, 42.2MB/s]
#
# model-00001-of-00002.safetensors:  20% 975M/4.97G [00:30<01:34, 42.2MB/s]
#
#
# consolidated.00.pth:  15% 954M/6.43G [00:30<02:04, 44.0MB/s]
#
# model-00001-of-00002.safetensors:  20% 986M/4.97G [00:30<01:34, 42.3MB/s]
#
#
# consolidated.00.pth:  15% 965M/6.43G [00:30<02:04, 43.9MB/s]
# model-00002-of-00002.safetensors:  68% 986M/1.46G [00:30<00:12, 38.3MB/s]
#
# model-00001-of-00002.safetensors:  20% 996M/4.97G [00:30<01:33, 42.5MB/s]
#
#
# consolidated.00.pth:  15% 975M/6.43G [00:30<02:06, 43.1MB/s]
# model-00002-of-00002.safetensors:  68% 996M/1.46G [00:30<00:13, 34.0MB/s]
#
# model-00001-of-00002.safetensors:  20% 1.01G/4.97G [00:30<01:32, 42.6MB/s]
#
#
# consolidated.00.pth:  15% 986M/6.43G [00:30<02:05, 43.2MB/s]
# model-00002-of-00002.safetensors:  69% 1.01G/1.46G [00:30<00:10, 42.4MB/s]
#
# model-00001-of-00002.safetensors:  20% 1.02G/4.97G [00:31<01:32, 42.7MB/s]
#
#
# consolidated.00.pth:  16% 996M/6.43G [00:31<02:06, 42.9MB/s]
# model-00002-of-00002.safetensors:  70% 1.02G/1.46G [00:31<00:10, 42.4MB/s]
#
# model-00001-of-00002.safetensors:  21% 1.03G/4.97G [00:31<01:32, 42.5MB/s]
#
#
# consolidated.00.pth:  16% 1.01G/6.43G [00:31<02:06, 42.9MB/s]
# model-00002-of-00002.safetensors:  70% 1.03G/1.46G [00:31<00:10, 42.2MB/s]
#
#
# consolidated.00.pth:  16% 1.02G/6.43G [00:34<08:30, 10.6MB/s]
#
# model-00001-of-00002.safetensors:  21% 1.04G/4.97G [00:34<06:17, 10.4MB/s]
#
#
# consolidated.00.pth:  16% 1.03G/6.43G [00:34<06:15, 14.4MB/s]
#
# model-00001-of-00002.safetensors:  21% 1.05G/4.97G [00:34<04:40, 14.0MB/s]
# model-00002-of-00002.safetensors:  71% 1.04G/1.46G [00:34<00:42, 10.0MB/s]
#
#
# consolidated.00.pth:  16% 1.04G/6.43G [00:34<04:47, 18.7MB/s]
#
# model-00001-of-00002.safetensors:  21% 1.06G/4.97G [00:34<03:29, 18.7MB/s]
# model-00002-of-00002.safetensors:  72% 1.05G/1.46G [00:34<00:30, 13.3MB/s]
#
#
# consolidated.00.pth:  16% 1.05G/6.43G [00:34<03:57, 22.7MB/s]
#
# model-00001-of-00002.safetensors:  22% 1.07G/4.97G [00:34<02:53, 22.5MB/s]
# model-00002-of-00002.safetensors:  73% 1.07G/1.46G [00:34<00:18, 20.9MB/s]
#
#
# consolidated.00.pth:  16% 1.06G/6.43G [00:34<03:23, 26.3MB/s]
#
# model-00001-of-00002.safetensors:  22% 1.08G/4.97G [00:34<02:28, 26.2MB/s]
# model-00002-of-00002.safetensors:  74% 1.08G/1.46G [00:35<00:15, 24.0MB/s]
#
#
# consolidated.00.pth:  17% 1.07G/6.43G [00:35<03:00, 29.6MB/s]
#
# model-00001-of-00002.safetensors:  22% 1.09G/4.97G [00:35<02:10, 29.6MB/s]
# model-00002-of-00002.safetensors:  75% 1.09G/1.46G [00:35<00:13, 27.1MB/s]
#
#
# consolidated.00.pth:  17% 1.08G/6.43G [00:35<02:43, 32.7MB/s]
#
# model-00001-of-00002.safetensors:  22% 1.10G/4.97G [00:35<01:58, 32.5MB/s]
# model-00002-of-00002.safetensors:  75% 1.10G/1.46G [00:35<00:11, 30.2MB/s]
#
#
# consolidated.00.pth:  17% 1.09G/6.43G [00:35<02:32, 35.1MB/s]
#
# model-00001-of-00002.safetensors:  22% 1.11G/4.97G [00:35<01:50, 35.0MB/s]
# model-00002-of-00002.safetensors:  76% 1.11G/1.46G [00:35<00:10, 32.9MB/s]
#
#
# consolidated.00.pth:  17% 1.10G/6.43G [00:35<02:24, 36.9MB/s]
#
# model-00001-of-00002.safetensors:  23% 1.12G/4.97G [00:35<01:44, 36.9MB/s]
# model-00002-of-00002.safetensors:  77% 1.12G/1.46G [00:36<00:09, 35.1MB/s]
#
#
# consolidated.00.pth:  17% 1.11G/6.43G [00:36<02:19, 38.2MB/s]
#
# model-00001-of-00002.safetensors:  23% 1.13G/4.97G [00:36<01:39, 38.4MB/s]
# model-00002-of-00002.safetensors:  78% 1.13G/1.46G [00:36<00:08, 37.1MB/s]
#
#
# consolidated.00.pth:  17% 1.12G/6.43G [00:36<02:15, 39.1MB/s]
#
# model-00001-of-00002.safetensors:  23% 1.14G/4.97G [00:36<01:37, 39.3MB/s]
# model-00002-of-00002.safetensors:  78% 1.14G/1.46G [00:36<00:08, 38.6MB/s]
#
#
# consolidated.00.pth:  18% 1.13G/6.43G [00:36<02:12, 40.0MB/s]
#
# model-00001-of-00002.safetensors:  23% 1.15G/4.97G [00:36<01:34, 40.4MB/s]
# model-00002-of-00002.safetensors:  79% 1.15G/1.46G [00:36<00:07, 39.5MB/s]
#
#
# consolidated.00.pth:  18% 1.14G/6.43G [00:36<02:09, 40.8MB/s]
#
# model-00001-of-00002.safetensors:  23% 1.16G/4.97G [00:36<01:33, 40.8MB/s]
#
# model-00001-of-00002.safetensors:  24% 1.17G/4.97G [00:40<07:21, 8.59MB/s]
#
#
# consolidated.00.pth:  18% 1.15G/6.43G [00:40<10:17, 8.53MB/s]
# model-00002-of-00002.safetensors:  80% 1.16G/1.46G [00:40<00:35, 8.39MB/s]
#
#
# consolidated.00.pth:  18% 1.16G/6.43G [00:40<07:26, 11.8MB/s]
# model-00002-of-00002.safetensors:  80% 1.17G/1.46G [00:40<00:24, 11.5MB/s]
#
# model-00001-of-00002.safetensors:  24% 1.18G/4.97G [00:40<05:22, 11.7MB/s]
#
#
# consolidated.00.pth:  18% 1.17G/6.43G [00:40<05:34, 15.7MB/s]
#
# model-00001-of-00002.safetensors:  24% 1.20G/4.97G [00:40<03:58, 15.8MB/s]
# model-00002-of-00002.safetensors:  81% 1.18G/1.46G [00:40<00:17, 15.4MB/s]
#
#
# consolidated.00.pth:  18% 1.18G/6.43G [00:40<04:30, 19.4MB/s]
#
# model-00001-of-00002.safetensors:  24% 1.21G/4.97G [00:40<03:13, 19.5MB/s]
# model-00002-of-00002.safetensors:  82% 1.20G/1.46G [00:40<00:13, 19.0MB/s]
#
# model-00001-of-00002.safetensors:  24% 1.22G/4.97G [00:41<02:40, 23.3MB/s]
#
#
# consolidated.00.pth:  19% 1.20G/6.43G [00:41<03:46, 23.1MB/s]
# model-00002-of-00002.safetensors:  83% 1.21G/1.46G [00:41<00:11, 22.7MB/s]
#
# model-00001-of-00002.safetensors:  25% 1.23G/4.97G [00:41<02:18, 27.1MB/s]
#
#
# consolidated.00.pth:  19% 1.21G/6.43G [00:41<03:16, 26.6MB/s]
# model-00002-of-00002.safetensors:  83% 1.22G/1.46G [00:41<00:09, 26.4MB/s]
#
# model-00001-of-00002.safetensors:  25% 1.24G/4.97G [00:41<02:03, 30.3MB/s]
#
#
# consolidated.00.pth:  19% 1.22G/6.43G [00:41<02:53, 30.1MB/s]
# model-00002-of-00002.safetensors:  84% 1.23G/1.46G [00:41<00:07, 29.8MB/s]
#
# model-00001-of-00002.safetensors:  25% 1.25G/4.97G [00:41<01:51, 33.2MB/s]
#
#
# consolidated.00.pth:  19% 1.23G/6.43G [00:41<02:38, 32.9MB/s]
# model-00002-of-00002.safetensors:  85% 1.24G/1.46G [00:41<00:06, 32.7MB/s]
#
# model-00001-of-00002.safetensors:  25% 1.26G/4.97G [00:42<01:44, 35.5MB/s]
#
#
# consolidated.00.pth:  19% 1.24G/6.43G [00:42<02:26, 35.4MB/s]
# model-00002-of-00002.safetensors:  85% 1.25G/1.46G [00:42<00:06, 34.9MB/s]
#
# model-00001-of-00002.safetensors:  26% 1.27G/4.97G [00:42<01:39, 37.1MB/s]
# model-00002-of-00002.safetensors:  86% 1.26G/1.46G [00:42<00:05, 37.2MB/s]
#
#
# consolidated.00.pth:  19% 1.25G/6.43G [00:42<02:18, 37.3MB/s]
#
# model-00001-of-00002.safetensors:  26% 1.28G/4.97G [00:42<01:35, 38.8MB/s]
#
#
# consolidated.00.pth:  20% 1.26G/6.43G [00:42<02:13, 38.6MB/s]
# model-00002-of-00002.safetensors:  87% 1.27G/1.46G [00:42<00:04, 38.4MB/s]
#
# model-00001-of-00002.safetensors:  26% 1.29G/4.97G [00:42<01:32, 39.7MB/s]
#
#
# consolidated.00.pth:  20% 1.27G/6.43G [00:42<02:10, 39.5MB/s]
# model-00002-of-00002.safetensors:  88% 1.28G/1.46G [00:42<00:04, 39.8MB/s]
#
# model-00001-of-00002.safetensors:  26% 1.30G/4.97G [00:43<01:30, 40.6MB/s]
# model-00002-of-00002.safetensors:  88% 1.29G/1.46G [00:43<00:04, 41.0MB/s]
#
#
# consolidated.00.pth:  20% 1.28G/6.43G [00:42<02:07, 40.5MB/s]
#
#
# consolidated.00.pth:  20% 1.29G/6.43G [00:43<02:26, 34.9MB/s]
#
#
# consolidated.00.pth:  20% 1.30G/6.43G [00:43<01:57, 43.6MB/s]
#
# model-00001-of-00002.safetensors:  26% 1.31G/4.97G [00:43<02:00, 30.4MB/s]
# model-00002-of-00002.safetensors:  89% 1.30G/1.46G [00:43<00:05, 29.8MB/s]
#
# model-00001-of-00002.safetensors:  27% 1.32G/4.97G [00:43<01:36, 37.7MB/s]
# model-00002-of-00002.safetensors:  90% 1.31G/1.46G [00:43<00:04, 36.0MB/s]
#
#
# consolidated.00.pth:  20% 1.31G/6.43G [00:43<01:56, 44.0MB/s]
#
# model-00001-of-00002.safetensors:  27% 1.33G/4.97G [00:43<01:19, 46.0MB/s]
# model-00002-of-00002.safetensors:  91% 1.32G/1.46G [00:43<00:03, 44.2MB/s]
#
# model-00001-of-00002.safetensors:  27% 1.34G/4.97G [00:44<01:16, 47.6MB/s]
# model-00002-of-00002.safetensors:  91% 1.33G/1.46G [00:44<00:02, 50.1MB/s]
#
#
# consolidated.00.pth:  21% 1.32G/6.43G [00:43<01:58, 43.3MB/s]
#
# model-00001-of-00002.safetensors:  27% 1.35G/4.97G [00:44<01:18, 46.0MB/s]
# model-00002-of-00002.safetensors:  92% 1.34G/1.46G [00:44<00:02, 47.4MB/s]
#
#
# consolidated.00.pth:  21% 1.33G/6.43G [00:44<01:59, 42.7MB/s]
#
# model-00001-of-00002.safetensors:  27% 1.36G/4.97G [00:44<01:20, 45.0MB/s]
# model-00002-of-00002.safetensors:  93% 1.35G/1.46G [00:44<00:02, 45.8MB/s]
#
#
# consolidated.00.pth:  21% 1.34G/6.43G [00:44<02:31, 33.5MB/s]
#
# model-00001-of-00002.safetensors:  28% 1.37G/4.97G [00:44<01:21, 44.3MB/s]
# model-00002-of-00002.safetensors:  93% 1.36G/1.46G [00:44<00:02, 44.7MB/s]
#
# model-00001-of-00002.safetensors:  28% 1.38G/4.97G [00:45<01:21, 43.9MB/s]
# model-00002-of-00002.safetensors:  94% 1.37G/1.46G [00:45<00:01, 43.8MB/s]
#
#
# consolidated.00.pth:  21% 1.36G/6.43G [00:45<01:54, 44.0MB/s]
#
# model-00001-of-00002.safetensors:  28% 1.39G/4.97G [00:45<01:22, 43.2MB/s]
# model-00002-of-00002.safetensors:  95% 1.38G/1.46G [00:45<00:01, 43.4MB/s]
#
#
# consolidated.00.pth:  21% 1.37G/6.43G [00:45<01:56, 43.5MB/s]
#
# model-00001-of-00002.safetensors:  28% 1.41G/4.97G [00:45<01:23, 42.8MB/s]
# model-00002-of-00002.safetensors:  96% 1.39G/1.46G [00:45<00:01, 43.4MB/s]
#
#
# consolidated.00.pth:  22% 1.38G/6.43G [00:45<01:56, 43.3MB/s]
#
# model-00001-of-00002.safetensors:  29% 1.42G/4.97G [00:45<01:22, 43.0MB/s]
# model-00002-of-00002.safetensors:  96% 1.41G/1.46G [00:45<00:01, 43.2MB/s]
#
#
# consolidated.00.pth:  22% 1.39G/6.43G [00:45<01:57, 43.0MB/s]
#
# model-00001-of-00002.safetensors:  29% 1.43G/4.97G [00:46<01:22, 42.7MB/s]
# model-00002-of-00002.safetensors:  97% 1.42G/1.46G [00:46<00:01, 43.1MB/s]
#
#
# consolidated.00.pth:  22% 1.41G/6.43G [00:45<01:57, 42.9MB/s]
# model-00002-of-00002.safetensors:  98% 1.43G/1.46G [00:46<00:00, 43.0MB/s]
#
# model-00001-of-00002.safetensors:  29% 1.44G/4.97G [00:46<01:26, 40.9MB/s]
#
#
# consolidated.00.pth:  22% 1.42G/6.43G [00:46<01:57, 42.7MB/s]
#
# model-00001-of-00002.safetensors:  29% 1.45G/4.97G [00:46<01:21, 43.1MB/s]
# model-00002-of-00002.safetensors:  98% 1.44G/1.46G [00:46<00:00, 42.8MB/s]
#
#
# consolidated.00.pth:  22% 1.43G/6.43G [00:46<01:57, 42.5MB/s]
# model-00002-of-00002.safetensors:  99% 1.45G/1.46G [00:46<00:00, 43.1MB/s]
#
# model-00001-of-00002.safetensors:  29% 1.46G/4.97G [00:46<01:21, 42.9MB/s]
#
#
# consolidated.00.pth:  22% 1.44G/6.43G [00:46<01:57, 42.3MB/s]
# model-00002-of-00002.safetensors: 100% 1.46G/1.46G [00:47<00:00, 42.9MB/s]
#
# model-00002-of-00002.safetensors: 100% 1.46G/1.46G [00:47<00:00, 31.0MB/s]
#
#
#
# consolidated.00.pth:  23% 1.45G/6.43G [00:46<01:57, 42.3MB/s]
#
# model-00001-of-00002.safetensors:  30% 1.48G/4.97G [00:47<01:22, 42.5MB/s]
#
#
# consolidated.00.pth:  23% 1.46G/6.43G [00:47<01:57, 42.3MB/s]
#
# model-00001-of-00002.safetensors:  30% 1.49G/4.97G [00:47<01:21, 42.5MB/s]
#
#
# consolidated.00.pth:  23% 1.47G/6.43G [00:47<01:57, 42.3MB/s]
#
# model-00001-of-00002.safetensors:  30% 1.50G/4.97G [00:48<02:20, 24.7MB/s]
#
# model-00001-of-00002.safetensors:  30% 1.51G/4.97G [00:50<05:07, 11.2MB/s]
#
#
# consolidated.00.pth:  23% 1.48G/6.43G [00:50<08:31, 9.68MB/s]
#
# model-00001-of-00002.safetensors:  31% 1.53G/4.97G [00:50<03:02, 18.8MB/s]
#
#
# consolidated.00.pth:  23% 1.50G/6.43G [00:50<05:01, 16.4MB/s]
#
# model-00001-of-00002.safetensors:  31% 1.54G/4.97G [00:50<02:36, 21.9MB/s]
#
#
# consolidated.00.pth:  23% 1.51G/6.43G [00:51<04:15, 19.2MB/s]
#
# model-00001-of-00002.safetensors:  31% 1.55G/4.97G [00:51<02:16, 25.1MB/s]
#
#
# consolidated.00.pth:  24% 1.52G/6.43G [00:51<03:38, 22.5MB/s]
#
# model-00001-of-00002.safetensors:  31% 1.56G/4.97G [00:51<02:01, 28.1MB/s]
#
#
# consolidated.00.pth:  24% 1.53G/6.43G [00:51<03:10, 25.7MB/s]
#
# model-00001-of-00002.safetensors:  32% 1.57G/4.97G [00:51<01:49, 31.0MB/s]
#
#
# consolidated.00.pth:  24% 1.54G/6.43G [00:51<02:48, 29.0MB/s]
#
# model-00001-of-00002.safetensors:  32% 1.58G/4.97G [00:51<01:40, 33.7MB/s]
#
#
# consolidated.00.pth:  24% 1.55G/6.43G [00:52<02:33, 31.8MB/s]
#
# model-00001-of-00002.safetensors:  32% 1.59G/4.97G [00:52<01:33, 35.9MB/s]
#
#
# consolidated.00.pth:  24% 1.56G/6.43G [00:52<02:21, 34.3MB/s]
#
# model-00001-of-00002.safetensors:  32% 1.60G/4.97G [00:52<01:29, 37.8MB/s]
#
#
# consolidated.00.pth:  24% 1.57G/6.43G [00:52<02:14, 36.2MB/s]
#
# model-00001-of-00002.safetensors:  33% 1.61G/4.97G [00:52<01:25, 39.1MB/s]
#
#
# consolidated.00.pth:  25% 1.58G/6.43G [00:52<02:08, 37.7MB/s]
#
# model-00001-of-00002.safetensors:  33% 1.63G/4.97G [00:52<01:23, 40.2MB/s]
#
#
# consolidated.00.pth:  25% 1.59G/6.43G [00:53<02:03, 39.1MB/s]
#
# model-00001-of-00002.safetensors:  33% 1.64G/4.97G [00:53<01:21, 40.8MB/s]
#
#
# consolidated.00.pth:  25% 1.60G/6.43G [00:53<01:59, 40.2MB/s]
#
# model-00001-of-00002.safetensors:  33% 1.65G/4.97G [00:53<01:20, 41.1MB/s]
#
#
# consolidated.00.pth:  25% 1.61G/6.43G [00:53<01:57, 41.0MB/s]
#
# model-00001-of-00002.safetensors:  33% 1.66G/4.97G [00:53<01:19, 41.5MB/s]
#
#
# consolidated.00.pth:  25% 1.63G/6.43G [00:53<01:55, 41.5MB/s]
#
# model-00001-of-00002.safetensors:  34% 1.67G/4.97G [00:53<01:18, 41.9MB/s]
#
#
# consolidated.00.pth:  25% 1.64G/6.43G [00:53<01:54, 41.9MB/s]
#
# model-00001-of-00002.safetensors:  34% 1.68G/4.97G [00:54<01:18, 42.1MB/s]
#
#
# consolidated.00.pth:  26% 1.65G/6.43G [00:54<01:54, 41.9MB/s]
#
# model-00001-of-00002.safetensors:  34% 1.69G/4.97G [00:54<01:17, 42.3MB/s]
#
#
# consolidated.00.pth:  26% 1.66G/6.43G [00:54<01:53, 42.1MB/s]
#
# model-00001-of-00002.safetensors:  34% 1.70G/4.97G [00:54<01:16, 42.4MB/s]
#
#
# consolidated.00.pth:  26% 1.67G/6.43G [00:54<01:55, 41.3MB/s]
#
# model-00001-of-00002.safetensors:  34% 1.71G/4.97G [00:54<01:16, 42.4MB/s]
#
#
# consolidated.00.pth:  26% 1.68G/6.43G [00:55<01:54, 41.6MB/s]
#
# model-00001-of-00002.safetensors:  35% 1.72G/4.97G [00:55<01:16, 42.4MB/s]
#
#
# consolidated.00.pth:  26% 1.69G/6.43G [00:55<01:52, 42.0MB/s]
#
# model-00001-of-00002.safetensors:  35% 1.73G/4.97G [00:55<01:16, 42.4MB/s]
#
#
# consolidated.00.pth:  26% 1.70G/6.43G [00:55<01:51, 42.3MB/s]
#
# model-00001-of-00002.safetensors:  35% 1.74G/4.97G [00:55<01:15, 42.6MB/s]
#
#
# consolidated.00.pth:  27% 1.71G/6.43G [00:55<01:51, 42.3MB/s]
#
# model-00001-of-00002.safetensors:  35% 1.75G/4.97G [00:55<01:15, 42.8MB/s]
#
#
# consolidated.00.pth:  27% 1.72G/6.43G [00:55<01:50, 42.5MB/s]
#
# model-00001-of-00002.safetensors:  35% 1.76G/4.97G [00:56<01:15, 42.5MB/s]
#
#
# consolidated.00.pth:  27% 1.73G/6.43G [00:56<01:50, 42.5MB/s]
#
# model-00001-of-00002.safetensors:
#
#
# consolidated.00.pth:  87% 5.60G/6.43G [02:35<00:19, 42.4MB/s]
#
#
# consolidated.00.pth:  87% 5.61G/6.43G [02:35<00:19, 42.6MB/s]
#
#
# consolidated.00.pth:  87% 5.62G/6.43G [02:35<00:18, 42.5MB/s]
#
#
# consolidated.00.pth:  88% 5.63G/6.43G [02:36<00:18, 42.3MB/s]
#
#
# consolidated.00.pth:  88% 5.64G/6.43G [02:36<00:18, 42.1MB/s]
#
#
# consolidated.00.pth:  88% 5.65G/6.43G [02:36<00:18, 42.3MB/s]
#
#
# consolidated.00.pth:  88% 5.66G/6.43G [02:36<00:17, 42.5MB/s]
#
#
# consolidated.00.pth:  88% 5.67G/6.43G [02:37<00:17, 42.4MB/s]
#
#
# consolidated.00.pth:  88% 5.68G/6.43G [02:37<00:17, 42.4MB/s]
#
#
# consolidated.00.pth:  89% 5.69G/6.43G [02:37<00:17, 42.3MB/s]
#
#
# consolidated.00.pth:  89% 5.70G/6.43G [02:37<00:17, 42.4MB/s]
#
#
# consolidated.00.pth:  89% 5.71G/6.43G [02:38<00:16, 42.5MB/s]
#
#
# consolidated.00.pth:  89% 5.73G/6.43G [02:38<00:16, 42.6MB/s]
#
#
# consolidated.00.pth:  89% 5.74G/6.43G [02:38<00:16, 42.6MB/s]
#
#
# consolidated.00.pth:  89% 5.75G/6.43G [02:38<00:16, 42.4MB/s]
#
#
# consolidated.00.pth:  90% 5.76G/6.43G [02:39<00:15, 42.5MB/s]
#
#
# consolidated.00.pth:  90% 5.77G/6.43G [02:39<00:15, 42.3MB/s]
#
#
# consolidated.00.pth:  90% 5.78G/6.43G [02:39<00:15, 42.4MB/s]
#
#
# consolidated.00.pth:  90% 5.79G/6.43G [02:39<00:15, 42.2MB/s]
#
#
# consolidated.00.pth:  90% 5.80G/6.43G [02:40<00:14, 42.0MB/s]
#
#
# consolidated.00.pth:  90% 5.81G/6.43G [02:40<00:14, 42.1MB/s]
#
#
# consolidated.00.pth:  91% 5.82G/6.43G [02:40<00:14, 42.4MB/s]
#
#
# consolidated.00.pth:  91% 5.83G/6.43G [02:40<00:14, 42.2MB/s]
#
#
# consolidated.00.pth:  91% 5.84G/6.43G [02:41<00:13, 42.3MB/s]
#
#
# consolidated.00.pth:  91% 5.85G/6.43G [02:41<00:13, 42.4MB/s]
#
#
# consolidated.00.pth:  91% 5.86G/6.43G [02:41<00:13, 42.5MB/s]
#
#
# consolidated.00.pth:  91% 5.87G/6.43G [02:41<00:13, 42.5MB/s]
#
#
# consolidated.00.pth:  92% 5.88G/6.43G [02:41<00:12, 42.5MB/s]
#
#
# consolidated.00.pth:  92% 5.89G/6.43G [02:42<00:12, 42.5MB/s]
#
#
# consolidated.00.pth:  92% 5.90G/6.43G [02:42<00:12, 42.6MB/s]
#
#
# consolidated.00.pth:  92% 5.91G/6.43G [02:42<00:12, 40.4MB/s]
#
#
# consolidated.00.pth:  92% 5.92G/6.43G [02:42<00:11, 43.4MB/s]
#
#
# consolidated.00.pth:  92% 5.93G/6.43G [02:43<00:11, 43.1MB/s]
# consolidated.00.pth:  98% 6.28G/6.43G [02:51<00:03, 42.2MB/s]
#
#
# consolidated.00.pth:  98% 6.29G/6.43G [02:51<00:03, 42.2MB/s]
#
#
# consolidated.00.pth:  98% 6.30G/6.43G [02:51<00:02, 42.3MB/s]
#
#
# consolidated.00.pth:  98% 6.31G/6.43G [02:52<00:02, 42.4MB/s]
#
#
# consolidated.00.pth:  98% 6.32G/6.43G [02:52<00:02, 42.2MB/s]
#
#
# consolidated.00.pth:  99% 6.33G/6.43G [02:52<00:02, 42.1MB/s]
#
#
# consolidated.00.pth:  99% 6.34G/6.43G [02:52<00:01, 42.1MB/s]
#
#
# consolidated.00.pth:  99% 6.35G/6.43G [02:53<00:01, 42.0MB/s]
#
#
# consolidated.00.pth:  99% 6.36G/6.43G [02:53<00:01, 42.4MB/s]
#
#
# consolidated.00.pth:  99% 6.38G/6.43G [02:53<00:01, 42.3MB/s]
#
#
# consolidated.00.pth:  99% 6.39G/6.43G [02:53<00:00, 41.5MB/s]
#
#
# consolidated.00.pth: 100% 6.40G/6.43G [02:54<00:00, 41.9MB/s]
#
#
# consolidated.00.pth: 100% 6.41G/6.43G [02:54<00:00, 42.0MB/s]
#
#
# consolidated.00.pth: 100% 6.42G/6.43G [02:54<00:00, 42.2MB/s]
#
#
# consolidated.00.pth: 100% 6.43G/6.43G [02:54<00:00, 36.7MB/s]
# Fetching 16 files: 100% 16/16 [02:55<00:00, 10.95s/it]
# Successfully downloaded model repo and wrote to the following locations:
# /content/Llama-3.2-3B-Instruct/tokenizer_config.json
# /content/Llama-3.2-3B-Instruct/model-00002-of-00002.safetensors
# /content/Llama-3.2-3B-Instruct/special_tokens_map.json
# /content/Llama-3.2-3B-Instruct/LICENSE.txt
# /content/Llama-3.2-3B-Instruct/model.safetensors.index.json
# /content/Llama-3.2-3B-Instruct/.gitattributes
# /content/Llama-3.2-3B-Instruct/model-00001-of-00002.safetensors
# /content/Llama-3.2-3B-Instruct/.cache
# /content/Llama-3.2-3B-Instruct/original
# /content/Llama-3.2-3B-Instruct/tokenizer.json
# /content/Llama-3.2-3B-Instruct/config.json
# /content/Llama-3.2-3B-Instruct/README.md
# /content/Llama-3.2-3B-Instruct/generation_config.json
# /content/Llama-3.2-3B-Instruct/USE_POLICY.md

# %% [markdown]
# ## Fine-tuning

# %%
config = """
# Model Arguments
model:
  _component_: torchtune.models.llama3_2.qlora_llama3_2_3b
  lora_attn_modules: ['q_proj', 'v_proj', 'output_proj']
  apply_lora_to_mlp: True
  apply_lora_to_output: False
  lora_rank: 64
  lora_alpha: 128
  lora_dropout: 0.0

# Tokenizer
tokenizer:
  _component_: torchtune.models.llama3.llama3_tokenizer
  path: ./Llama-3.2-3B-Instruct/original/tokenizer.model
  max_seq_len: null

checkpointer:
  _component_: torchtune.training.FullModelHFCheckpointer
  checkpoint_dir: ./Llama-3.2-3B-Instruct
  checkpoint_files: [
    model-00001-of-00002.safetensors,
    model-00002-of-00002.safetensors,
  ]
  recipe_checkpoint: null
  output_dir: ./checkpoints
  model_type: LLAMA3_2
resume_from_checkpoint: False
save_adapter_weights_only: False

# Dataset and Sampler
dataset:
  _component_: torchtune.datasets.instruct_dataset
  data_files: ./train_data.json
  source: json
  split: train
seed: 42
shuffle: True
batch_size: 1
#batch_size: 4

# Optimizer and Scheduler
optimizer:
  _component_: torch.optim.AdamW
  fused: True
  weight_decay: 0.01
  lr: 3e-4
lr_scheduler:
  _component_: torchtune.modules.get_cosine_schedule_with_warmup
  num_warmup_steps: 100

loss:
  _component_: torchtune.modules.loss.CEWithChunkedOutputLoss

# Training
epochs: 4
max_steps_per_epoch: null
gradient_accumulation_steps: 4
compile: False # set it to True for better memory and performance
# compile: True # set it to True for better memory and performance

# Logging
output_dir: ./logs
metric_logger:
  _component_: torchtune.training.metric_logging.TensorBoardLogger
  log_dir: ${output_dir}
log_every_n_steps: 1
log_peak_memory_stats: False

# Environment
device: cuda
dtype: bf16

# Activations Memory
enable_activation_checkpointing: False
enable_activation_offloading: False

# Profiler (disabled)
profiler:
  _component_: torchtune.training.setup_torch_profiler
  enabled: False

  #Output directory of trace artifacts
  output_dir: ${output_dir}/profiling_outputs

  #`torch.profiler.ProfilerActivity` types to trace
  cpu: True
  cuda: True

  #trace options passed to `torch.profiler.profile`
  profile_memory: False
  with_stack: False
  record_shapes: True
  with_flops: False

  # `torch.profiler.schedule` options:
  # wait_steps -> wait, warmup_steps -> warmup, active_steps -> active, num_cycles -> repeat
  wait_steps: 5
  warmup_steps: 5
  active_steps: 2
  num_cycles: 1
"""

# %%
Path("custom_config.yaml").write_text(config)
# Out:
# 2397

# %%
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %%
# !tune run lora_finetune_single_device --config "custom_config.yaml" epochs=2
# Out:
# INFO:torchtune.utils._logging:Running LoRAFinetuneRecipeSingleDevice with resolved config:
#
# batch_size: 1
# checkpointer:
#   _component_: torchtune.training.FullModelHFCheckpointer
#   checkpoint_dir: ./Llama-3.2-3B-Instruct
#   checkpoint_files:
#   - model-00001-of-00002.safetensors
#   - model-00002-of-00002.safetensors
#   model_type: LLAMA3_2
#   output_dir: ./checkpoints
#   recipe_checkpoint: null
# compile: false
# dataset:
#   _component_: torchtune.datasets.instruct_dataset
#   data_files: ./train_data.json
#   source: json
#   split: train
# device: cuda
# dtype: bf16
# enable_activation_checkpointing: false
# enable_activation_offloading: false
# epochs: 2
# gradient_accumulation_steps: 4
# log_every_n_steps: 1
# log_peak_memory_stats: false
# loss:
#   _component_: torchtune.modules.loss.CEWithChunkedOutputLoss
# lr_scheduler:
#   _component_: torchtune.modules.get_cosine_schedule_with_warmup
#   num_warmup_steps: 100
# max_steps_per_epoch: null
# metric_logger:
#   _component_: torchtune.training.metric_logging.TensorBoardLogger
#   log_dir: ./logs
# model:
#   _component_: torchtune.models.llama3_2.qlora_llama3_2_3b
#   apply_lora_to_mlp: true
#   apply_lora_to_output: false
#   lora_alpha: 128
#   lora_attn_modules:
#   - q_proj
#   - v_proj
#   - output_proj
#   lora_dropout: 0.0
#   lora_rank: 64
# optimizer:
#   _component_: torch.optim.AdamW
#   fused: true
#   lr: 0.0003
#   weight_decay: 0.01
# output_dir: ./logs
# profiler:
#   _component_: torchtune.training.setup_torch_profiler
#   active_steps: 2
#   cpu: true
#   cuda: true
#   enabled: false
#   num_cycles: 1
#   output_dir: ./logs/profiling_outputs
#   profile_memory: false
#   record_shapes: true
#   wait_steps: 5
#   warmup_steps: 5
#   with_flops: false
#   with_stack: false
# resume_from_checkpoint: false
# save_adapter_weights_only: false
# seed: 42
# shuffle: true
# tokenizer:
#   _component_: torchtune.models.llama3.llama3_tokenizer
#   max_seq_len: null
#   path: ./Llama-3.2-3B-Instruct/original/tokenizer.model
#
# DEBUG:torchtune.utils._logging:Setting manual seed to local seed 42. Local seed is seed + rank = 42 + 0
# 2024-12-09 20:04:01.320376: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-09 20:04:01.340270: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-09 20:04:01.346798: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-09 20:04:02.767115: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO:torchtune.utils._logging:Model is initialized with precision torch.bfloat16.
# INFO:torchtune.utils._logging:Memory stats after model init:
# 	GPU peak memory allocation: 2.51 GiB
# 	GPU peak memory reserved: 2.64 GiB
# 	GPU peak memory active: 2.51 GiB
# INFO:torchtune.utils._logging:Tokenizer is initialized from file.
# INFO:torchtune.utils._logging:Optimizer and loss are initialized.
# INFO:torchtune.utils._logging:Loss is initialized.
# Generating train split: 233 examples [00:00, 2306.93 examples/s]
# INFO:torchtune.utils._logging:Dataset and Sampler are initialized.
# INFO:torchtune.utils._logging:Learning rate scheduler is initialized.
# WARNING:torchtune.utils._logging: Profiling disabled.
# INFO:torchtune.utils._logging: Profiler config after instantiation: {'enabled': False}
# 1|58|Loss: 0.11433608829975128: 100% 58/58 [25:42<00:00, 26.62s/it]INFO:torchtune.utils._logging:Starting checkpoint save...
# INFO:torchtune.utils._logging:Model checkpoint of size 4.97 GB saved to checkpoints/hf_model_0001_0.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 1.46 GB saved to checkpoints/hf_model_0002_0.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.18 GB saved to checkpoints/adapter_0.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.18 GB saved to checkpoints/adapter_model.bin
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.00 GB saved to checkpoints/adapter_config.json
# INFO:torchtune.utils._logging:Recipe checkpoint of size 0.36 GB saved to checkpoints/recipe_state.pt
# INFO:torchtune.utils._logging:Checkpoint saved in 513.63 seconds.
#
# 1|58|Loss: 0.11433608829975128: 100% 58/58 [34:21<00:00, 35.55s/it]
#
#   2% 1/58 [00:26<24:46, 26.08s/it]
# 2|59|Loss: 0.2202570140361786:   2% 1/58 [00:26<24:46, 26.08s/it]
# 2|59|Loss: 0.2202570140361786:   3% 2/58 [00:52<24:37, 26.39s/it]
# 2|60|Loss: 0.0025418438017368317:   3% 2/58 [00:52<24:37, 26.39s/it]
# 2|60|Loss: 0.0025418438017368317:   5% 3/58 [01:19<24:18, 26.51s/it]
# 2|61|Loss: 0.015186071395874023:   5% 3/58 [01:19<24:18, 26.51s/it]
# 2|61|Loss: 0.015186071395874023:   7% 4/58 [01:45<23:50, 26.50s/it]
# 2|62|Loss: 0.08190034329891205:   7% 4/58 [01:45<23:50, 26.50s/it]
# 2|62|Loss: 0.08190034329891205:   9% 5/58 [02:12<23:23, 26.48s/it]
# 2|113|Loss: 0.02082826942205429:  95% 55/58 [24:25<01:20, 26.74s/it]
# 2|113|Loss: 0.02082826942205429:  97% 56/58 [24:51<00:53, 26.69s/it]
# 2|114|Loss: 0.0026559033431112766:  97% 56/58 [24:51<00:53, 26.69s/it]
# 2|114|Loss: 0.0026559033431112766:  98% 57/58 [25:18<00:26, 26.73s/it]
# 2|115|Loss: 0.03696072846651077:  98% 57/58 [25:18<00:26, 26.73s/it]
# 2|115|Loss: 0.03696072846651077: 100% 58/58 [25:45<00:00, 26.82s/it]
# 2|116|Loss: 0.002564503811299801: 100% 58/58 [25:45<00:00, 26.82s/it]INFO:torchtune.utils._logging:Starting checkpoint save...
# INFO:torchtune.utils._logging:Model checkpoint of size 4.97 GB saved to checkpoints/hf_model_0001_1.pt
# INFO:torchtune.utils._logging:Model checkpoint of size 1.46 GB saved to checkpoints/hf_model_0002_1.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.18 GB saved to checkpoints/adapter_1.pt
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.18 GB saved to checkpoints/adapter_model.bin
# INFO:torchtune.utils._logging:Adapter checkpoint of size 0.00 GB saved to checkpoints/adapter_config.json
# INFO:torchtune.utils._logging:Saving final epoch checkpoint.
# INFO:torchtune.utils._logging:The full model checkpoint, including all weights and configurations, has been saved successfully.You can now use this checkpoint for further training or inference.
# INFO:torchtune.utils._logging:Checkpoint saved in 593.21 seconds.
# 2|116|Loss: 0.002564503811299801: 100% 58/58 [35:45<00:00, 36.99s/it]

# %% [markdown]
# ## Upload model

# %%
# !mkdir hf_repo

# %%
# !cp "checkpoints/hf_model_0002_0.pt" "hf_repo/"
# !cp "checkpoints/hf_model_0002_1.pt" "hf_repo/"
# !cp "checkpoints/config.json" "hf_repo/"
# !cp "Llama-3.2-3B-Instruct/original/tokenizer.model" "hf_repo/"
# !cp "Llama-3.2-3B-Instruct/generation_config.json" "hf_repo/"
# !cp "Llama-3.2-3B-Instruct/tokenizer.json" "hf_repo/"
# !cp "Llama-3.2-3B-Instruct/tokenizer_config.json" "hf_repo/"
# !cp "Llama-3.2-3B-Instruct/special_tokens_map.json" "hf_repo/"
# !cp "Llama-3.2-3B-Instruct/LICENSE.txt" "hf_repo/"
# !cp "Llama-3.2-3B-Instruct/README.md" "hf_repo/"
# !cp "Llama-3.2-3B-Instruct/USE_POLICY.md" "hf_repo/"

# %%
MODEL_PATH = "hf_repo"

tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)
model = AutoModelForCausalLM.from_pretrained(MODEL_PATH).to("cuda")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-28-de672d144fe4> in <cell line: 4>()
#       2
#       3 tokenizer = AutoTokenizer.from_pretrained(MODEL_PATH)
# ----> 4 model = AutoModelForCausalLM.from_pretrained(MODEL_PATH).to("cuda")
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562         elif type(config) in cls._model_mapping.keys():
#     563             model_class = _get_model_class(config, cls._model_mapping)
# --> 564             return model_class.from_pretrained(
#     565                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    3761                     )
#    3762                 else:
# -> 3763                     raise EnvironmentError(
#    3764                         f"Error no file named {_add_variant(WEIGHTS_NAME, variant)}, {_add_variant(SAFE_WEIGHTS_NAME, variant)},"
#    3765                         f" {TF2_WEIGHTS_NAME}, {TF_WEIGHTS_NAME + '.index'} or {FLAX_WEIGHTS_NAME} found in directory"
#
# OSError: Error no file named pytorch_model.bin, model.safetensors, tf_model.h5, model.ckpt.index or flax_model.msgpack found in directory hf_repo.

# %% [markdown]
# ## Evaluation

# %%
pipe = pipeline(
    task="text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=256,
    temperature=0.000001,
    return_full_text=False,
    model_kwargs={"torch_dtype": torch.bfloat16},
    pad_token_id=tokenizer.eos_token_id,
    device="cuda",
)

# %%
question = "What is the total premium for march 2023"
user_question = create_prompt(question)
prompt = [
    {"role": "user", "content": user_question},
]
output = pipe(prompt)
output[0]["generated_text"]

# %%
question = "What is the total premium by gender"
user_question = create_prompt(question)
prompt = [
    {"role": "user", "content": user_question},
]
output = pipe(prompt)
output[0]["generated_text"]
# Out:
# "{'name': 'get_metric', 'parameters': {'metric': 'get_premium', 'filters': {'gender':'m'}, 'groupby': none}}"

# %%
question = "What is the total premium?"
user_question = create_prompt(question)
prompt = [
    {"role": "user", "content": user_question},
]
output = pipe(prompt)
output[0]["generated_text"]
# Out:
# "{'name': 'get_metric', 'parameters': {'metric': 'get_premium', 'filters': {'povider_network': 'NW6'}, 'groupby': none}}"

# %%
test_data = json.loads(Path("test_data.json").read_text())

# %%
prompt = test_data[4]["input"]
print(prompt)
# Out:
# Classify the text for one of the categories:
#
# <text>
# Has anyone been able to get on disability due to just your mental illnesses? I’ve tried three times, sent in all required paperwork and have been denied every time. I have severe depression, severe social and generalized anxiety/slight agoraphobia, bipolar, autism, ptsd and ADHD. I can’t work and it’s ruining my life
# </text>
#
# Choose from one of the category:
# normal, depression, suicidal, anxiety, bipolar, stress, personality disorder
# Only choose one category, the most appropriate one. Reply only with the category.

# %%
predictions = []
for example in tqdm(test_data):
    statement = example["input"]
    prompt = [
        {"role": "user", "content": statement},
    ]
    output = pipe(prompt)
    predictions.append(output[0]["generated_text"])
# Out:
# 100%|██████████| 5052/5052 [10:29<00:00,  8.03it/s]

# %%
pd.Series(predictions).value_counts()
# Out:
# suicidal                1017
# depression               968
# normal                   968
# anxiety                  821
# stress                   549
# bipolar                  537
# personality disorder     192
# Name: count, dtype: int64

# %%
eval_df = pd.DataFrame.from_dict({"label": true_values, "prediction": predictions})
eval_df.head()
# Out:
#         label  prediction
# 0  depression    suicidal
# 1  depression  depression
# 2    suicidal    suicidal
# 3     anxiety     anxiety
# 4     bipolar     bipolar

# %%
accuracy_score(true_values, predictions)
# Out:
# 0.8489707046714172

# %%
print(classification_report(eval_df.label, eval_df.prediction))
# Out:
#                       precision    recall  f1-score   support
#
#              anxiety       0.88      0.92      0.90       787
#              bipolar       0.93      0.88      0.91       565
#           depression       0.76      0.74      0.75       988
#               normal       0.95      0.94      0.94       981
# personality disorder       0.84      0.81      0.82       200
#               stress       0.84      0.84      0.84       552
#             suicidal       0.78      0.81      0.79       979
#
#             accuracy                           0.85      5052
#            macro avg       0.85      0.85      0.85      5052
#         weighted avg       0.85      0.85      0.85      5052

# %% [markdown]
# ## References
#
# - [Trained model on HF](https://huggingface.co/curiousily/Llama-3.2-1B-Mental-Health-Sentiment)
# - [Sentiment analysis for mental health dataset](https://huggingface.co/datasets/btwitssayan/sentiment-analysis-for-mental-health)
